# %%
import numpy as np
import pandas as pd
import transformers
import torch
import re
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from torch import nn
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('/content/train.csv')
data.drop(['doi','url','publication month', 'publication year','publisher', 'data_index'], axis =1 , inplace = True)
data = data.dropna()
data["text"] = data["title"] + data["abstract"]
data
# Out:
#                                                 abstract  \
# 0      the production of b jets in association with a...
# 1      instabilities in the price dynamics of a large...
# 2      large information sizes in samples and feature...
# 3      we consider polygonal billiards with collision...
# 4      Bauxite deposits of Jharkhand in India are res...
# ...                                                  ...
# 41534  programs offered by academic institutions in h...
# 41535  this research addresses the competencies organ...
# 41536  this paper studies an optimal stopping problem...
# 41537  we examine the possible extension of the param...
# 41539  what happens to the entropy increase principle...
#
#                                                   author  \
# 0                                      CMS Collaboration
# 1      Giacomo Bormetti, Lucio Maria Calcagnile, Mich...
# 2                                 David Banh, Alan Huang
# 3      Gianluigi Del Magno, Jo\~ao Lopes Dias, Pedro ...
# 4      ['E.N. Dhanamjaya Rao', 'A.T. Jeyaseelan', 'K....
# ...                                                  ...
# 41534                  ['Alex Ferworn', 'Muthana Zouri']
# 41535        ['Sabik Khan', 'Marcus Ho', 'Kamrul Ahsan']
# 41536                          Diana Dorobantu (LSProba)
# 41537  John Ellis, Joel Giedt, Oleg Lebedev, Keith Ol...
# 41539                                            K.Ghosh
#
#                                                    title  \
# 0      Measurement of the Z/gamma* + b-jet cross sect...
# 1      Modelling systemic price cojumps with Hawkes f...
# 2      Encoding large information structures in linea...
# 3      Hyperbolic polygonal billiards close to 1-dime...
# 4      analysis of aster data for mapping bauxite ric...
# ...                                                  ...
# 41534  an ontology-based approach for curriculum mapp...
# 41535  recruiting project managers: a comparative ana...
# 41536  Optimal stopping for L\'evy processes and affi...
# 41537                               Against Tachyophobia
# 41539  Studies on Some Aspects of the Fundamental The...
#
#                                     label  \
# 0                                 Physics
# 1                    Quantitative Finance
# 2                        Machine Learning
# 3              Dynamics/Dynamical Systems
# 4                               Sociology
# ...                                   ...
# 41534                Computer Engineering
# 41535                           Sociology
# 41536          Statistics and Probability
# 41537                             Physics
# 41539  Cosmology, Relativity, and Gravity
#
#                                                     text
# 0      Measurement of the Z/gamma* + b-jet cross sect...
# 1      Modelling systemic price cojumps with Hawkes f...
# 2      Encoding large information structures in linea...
# 3      Hyperbolic polygonal billiards close to 1-dime...
# 4      analysis of aster data for mapping bauxite ric...
# ...                                                  ...
# 41534  an ontology-based approach for curriculum mapp...
# 41535  recruiting project managers: a comparative ana...
# 41536  Optimal stopping for L\'evy processes and affi...
# 41537  Against Tachyophobiawe examine the possible ex...
# 41539  Studies on Some Aspects of the Fundamental The...
#
# [40332 rows x 5 columns]

# %%
def NLP_cleaning(text):
    text_corpus = []
    i=0
    for sent in tqdm(text, desc='Cleaning'):
        # print(i, end =" ")
        i+=1
        sent = re.sub('<[^>]*>', '', sent)
        sent = re.sub('[^a-zA-z0-9]', ' ', sent)
        sent = sent.lower()
        text_corpus.append(sent)

    return text_corpus

# %%
text = data.text.values.tolist()
text_corpus = NLP_cleaning(text)
data['text'] = text_corpus
data['title'] = NLP_cleaning(data.title.values.tolist())
data['author'] = NLP_cleaning(data.author.values.tolist())
# Out:
# Cleaning: 100%|██████████| 40332/40332 [00:01<00:00, 20856.11it/s]
# Cleaning: 100%|██████████| 40332/40332 [00:00<00:00, 182919.88it/s]
# Cleaning: 100%|██████████| 40332/40332 [00:00<00:00, 136383.20it/s]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['label_number'] = label_encoder.fit_transform(data['label'])
data
# Out:
#                                                 abstract  \
# 0      the production of b jets in association with a...
# 1      instabilities in the price dynamics of a large...
# 2      large information sizes in samples and feature...
# 3      we consider polygonal billiards with collision...
# 4      Bauxite deposits of Jharkhand in India are res...
# ...                                                  ...
# 41534  programs offered by academic institutions in h...
# 41535  this research addresses the competencies organ...
# 41536  this paper studies an optimal stopping problem...
# 41537  we examine the possible extension of the param...
# 41539  what happens to the entropy increase principle...
#
#                                                   author  \
# 0                                      cms collaboration
# 1      giacomo bormetti  lucio maria calcagnile  mich...
# 2                                 david banh  alan huang
# 3      gianluigi del magno  jo\ ao lopes dias  pedro ...
# 4      [ e n  dhanamjaya rao    a t  jeyaseelan    k ...
# ...                                                  ...
# 41534                  [ alex ferworn    muthana zouri ]
# 41535        [ sabik khan    marcus ho    kamrul ahsan ]
# 41536                          diana dorobantu  lsproba
# 41537  john ellis  joel giedt  oleg lebedev  keith ol...
# 41539                                            k ghosh
#
#                                                    title  \
# 0      measurement of the z gamma    b jet cross sect...
# 1      modelling systemic price cojumps with hawkes f...
# 2      encoding large information structures in linea...
# 3      hyperbolic polygonal billiards close to 1 dime...
# 4      analysis of aster data for mapping bauxite ric...
# ...                                                  ...
# 41534  an ontology based approach for curriculum mapp...
# 41535  recruiting project managers  a comparative ana...
# 41536  optimal stopping for l\ evy processes and affi...
# 41537                               against tachyophobia
# 41539  studies on some aspects of the fundamental the...
#
#                                     label  \
# 0                                 Physics
# 1                    Quantitative Finance
# 2                        Machine Learning
# 3              Dynamics/Dynamical Systems
# 4                               Sociology
# ...                                   ...
# 41534                Computer Engineering
# 41535                           Sociology
# 41536          Statistics and Probability
# 41537                             Physics
# 41539  Cosmology, Relativity, and Gravity
#
#                                                     text  label_number
# 0      measurement of the z gamma    b jet cross sect...            95
# 1      modelling systemic price cojumps with hawkes f...           105
# 2      encoding large information structures in linea...            67
# 3      hyperbolic polygonal billiards close to 1 dime...            41
# 4      analysis of aster data for mapping bauxite ric...           114
# ...                                                  ...           ...
# 41534  an ontology based approach for curriculum mapp...            25
# 41535  recruiting project managers  a comparative ana...           114
# 41536  optimal stopping for l\ evy processes and affi...           118
# 41537  against tachyophobiawe examine the possible ex...            95
# 41539  studies on some aspects of the fundamental the...            34
#
# [40332 rows x 6 columns]

# %%
val_df = pd.read_csv('/content/val.csv')
val_df.drop(['doi','url','publication month', 'publication year','publisher', 'data_index'], axis =1 , inplace = True)
val_df = val_df.dropna()
val_df['label_number'] = label_encoder.transform(val_df['label'])
val_df["text"] = val_df["title"] + val_df["abstract"]
val_df['title'] = NLP_cleaning(val_df.title.values.tolist())
val_df['author'] = NLP_cleaning(val_df.author.values.tolist())
val_df['abstract'] = NLP_cleaning(val_df.abstract.values.tolist())
val_df['text'] = NLP_cleaning(val_df.text.values.tolist())
# Out:
# Cleaning: 100%|██████████| 8648/8648 [00:00<00:00, 189120.37it/s]
# Cleaning: 100%|██████████| 8648/8648 [00:00<00:00, 131319.23it/s]
# Cleaning: 100%|██████████| 8648/8648 [00:00<00:00, 19616.33it/s]
# Cleaning: 100%|██████████| 8648/8648 [00:00<00:00, 19575.34it/s]

# %%
X=val_df[['text']].copy()
y=val_df[['label_number']].copy()

# %%
val_text, test_text, val_labels, test_labels = train_test_split(X,y,random_state=2018,test_size=0.4,shuffle=True)

# %%
train_text = data[["abstract","author","title","text"]].copy()

# %%
# !pip install -q sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.3.1-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.8/132.8 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.3.1

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from sklearn.svm import SVC
svm_classifier = SVC()

# %%
abc = data['text']
abc = abc.to_list()

# %%
embeddings = model.encode(abc)

# %%
abco = data['label_number']
abco = abco.to_list()

# %%
svm_classifier.fit(embeddings,abco)
# Out:
# SVC()

# %%
abc = test_text['text']
abc = abc.to_list()

# %%
embeddings = model.encode(abc)

# %%
y_pred = svm_classifier.predict(embeddings)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(test_labels, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.76        43
#            1       0.85      0.80      0.82        50
#            2       0.67      0.74      0.70        53
#            3       1.00      1.00      1.00         7
#            4       0.62      0.45      0.53        44
#            5       0.14      0.11      0.12         9
#            6       0.54      0.44      0.48        34
#            7       0.80      0.67      0.73         6
#            8       0.55      0.74      0.63       220
#            9       0.50      0.50      0.50         4
#           10       0.68      0.64      0.66        95
#           12       0.70      0.92      0.80        78
#           13       0.60      0.25      0.35        12
#           14       0.00      0.00      0.00         1
#           15       0.67      0.50      0.57         4
#           16       0.00      0.00      0.00         1
#           17       0.83      0.62      0.71        16
#           19       0.00      0.00      0.00         1
#           20       0.83      0.36      0.50        14
#           21       0.00      0.00      0.00         3
#           22       1.00      0.20      0.33         5
#           23       0.78      0.92      0.84        76
#           24       0.00      0.00      0.00         5
#           25       0.64      0.53      0.58        17
#           26       0.83      0.62      0.71         8
#           27       0.30      0.17      0.22        40
#           28       0.79      0.95      0.86       101
#           29       0.90      0.60      0.72        15
#           30       0.09      0.12      0.11         8
#           31       0.51      0.39      0.44        71
#           32       0.00      0.00      0.00         4
#           33       0.78      0.32      0.45        57
#           34       0.64      0.80      0.71        65
#           35       0.91      0.95      0.93        21
#           36       0.00      0.00      0.00         4
#           37       0.54      0.62      0.58        24
#           38       0.64      0.77      0.70        35
#           39       0.00      0.00      0.00         1
#           40       0.75      0.83      0.79        66
#           41       0.82      0.78      0.80       113
#           42       1.00      0.57      0.73         7
#           43       0.93      0.93      0.93        14
#           44       0.00      0.00      0.00         3
#           45       0.00      0.00      0.00         2
#           46       0.55      0.79      0.65        14
#           47       0.00      0.00      0.00         1
#           49       0.45      0.38      0.42        13
#           50       0.50      0.40      0.44         5
#           51       0.82      0.41      0.55        78
#           52       0.76      0.84      0.80        31
#           53       0.00      0.00      0.00         1
#           54       0.78      0.89      0.83        80
#           56       1.00      0.25      0.40         4
#           57       1.00      0.50      0.67         6
#           58       0.00      0.00      0.00         4
#           59       0.86      0.67      0.75         9
#           60       1.00      0.14      0.25         7
#           61       0.67      0.70      0.68        20
#           62       1.00      0.11      0.20         9
#           63       0.73      0.54      0.62        35
#           64       0.78      0.58      0.67        12
#           65       1.00      1.00      1.00         3
#           66       0.64      0.54      0.58        13
#           67       0.50      0.58      0.54        31
#           68       0.71      0.69      0.70       102
#           69       0.00      0.00      0.00         1
#           70       0.64      0.60      0.62        72
#           71       0.00      0.00      0.00         4
#           72       0.00      0.00      0.00         2
#           73       0.68      0.86      0.76        35
#           74       0.60      0.43      0.50         7
#           75       0.92      0.92      0.92        12
#           76       1.00      0.33      0.50         3
#           77       1.00      0.85      0.92        20
#           78       0.50      0.50      0.50         4
#           79       0.00      0.00      0.00         1
#           80       1.00      0.75      0.86         4
#           82       0.70      0.88      0.78         8
#           83       0.00      0.00      0.00         2
#           84       0.62      0.58      0.60        76
#           85       0.77      0.87      0.82        39
#           86       0.58      0.58      0.58        19
#           88       0.91      1.00      0.95        10
#           89       1.00      1.00      1.00         3
#           90       0.67      0.89      0.76        18
#           91       0.73      0.81      0.77        37
#           92       0.00      0.00      0.00         1
#           93       0.57      0.51      0.54        51
#           94       0.00      0.00      0.00         1
#           95       0.75      0.85      0.80       376
#           96       0.67      0.67      0.67         3
#           97       0.44      0.27      0.33        15
#           98       0.84      0.73      0.78        22
#           99       0.00      0.00      0.00         2
#          100       0.86      0.60      0.71        10
#          101       0.70      0.70      0.70        10
#          102       0.00      0.00      0.00         0
#          103       0.75      0.67      0.71         9
#          104       1.00      0.17      0.29         6
#          105       0.40      1.00      0.57         2
#          106       0.00      0.00      0.00         5
#          107       0.84      0.88      0.86       314
#          108       0.79      0.93      0.85        28
#          109       1.00      1.00      1.00         3
#          110       1.00      1.00      1.00         1
#          111       0.76      0.76      0.76        25
#          112       0.67      0.48      0.56        21
#          113       1.00      0.09      0.17        11
#          114       1.00      0.50      0.67         2
#          115       0.76      0.88      0.81        32
#          116       0.00      0.00      0.00         3
#          117       0.63      0.71      0.67        24
#          118       0.71      0.82      0.76        50
#          119       0.70      0.65      0.68        78
#          120       0.62      0.72      0.67        36
#          121       0.00      0.00      0.00         1
#          122       1.00      1.00      1.00         6
#
#     accuracy                           0.71      3460
#    macro avg       0.58      0.50      0.52      3460
# weighted avg       0.71      0.71      0.69      3460

# %% [markdown]
# # Proper Experiment

# %%
X_train = data['text']
X_train = X_train.to_list()
Y_train = data['label_number']
Y_train = Y_train.to_list()

# %%
X_test = val_df['text'].to_list()
Y_test = val_df['label_number'].to_list()

# %%
train_embeddings = model.encode(X_train)
test_embeddings = model.encode(X_test)

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
svm = SVC()

svm_classifier.fit(train_embeddings,Y_train)
y_pred = svm_classifier.predict(test_embeddings)

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ",accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.7119565217391305
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.73      0.72        99
#            1       0.80      0.80      0.80       126
#            2       0.64      0.70      0.67       130
#            3       0.86      1.00      0.92        12
#            4       0.62      0.52      0.56       118
#            5       0.43      0.20      0.27        30
#            6       0.61      0.50      0.55       104
#            7       0.71      0.56      0.63         9
#            8       0.52      0.71      0.60       557
#            9       0.60      0.27      0.37        11
#           10       0.68      0.68      0.68       225
#           11       0.00      0.00      0.00         3
#           12       0.70      0.92      0.80       189
#           13       0.70      0.33      0.45        42
#           14       0.00      0.00      0.00         3
#           15       0.83      0.56      0.67         9
#           16       0.00      0.00      0.00         2
#           17       0.78      0.78      0.78        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.81      0.38      0.52        34
#           21       0.00      0.00      0.00         9
#           22       0.67      0.55      0.60        11
#           23       0.71      0.93      0.81       167
#           24       0.00      0.00      0.00         9
#           25       0.73      0.55      0.63        29
#           26       0.70      0.70      0.70        20
#           27       0.40      0.23      0.29       100
#           28       0.82      0.95      0.88       268
#           29       0.95      0.67      0.78        27
#           30       0.32      0.29      0.30        24
#           31       0.54      0.43      0.48       179
#           32       0.50      0.21      0.30        19
#           33       0.78      0.30      0.43       135
#           34       0.67      0.77      0.72       180
#           35       0.81      0.90      0.85        69
#           36       0.00      0.00      0.00         4
#           37       0.53      0.58      0.55        53
#           38       0.57      0.75      0.65        87
#           39       0.25      0.25      0.25         4
#           40       0.79      0.81      0.80       180
#           41       0.78      0.77      0.78       272
#           42       1.00      0.55      0.71        20
#           43       0.86      0.94      0.90        33
#           44       0.00      0.00      0.00         4
#           45       0.00      0.00      0.00         5
#           46       0.48      0.75      0.59        20
#           47       0.67      0.14      0.24        14
#           49       0.54      0.41      0.47        34
#           50       0.79      0.73      0.76        15
#           51       0.75      0.41      0.53       175
#           52       0.72      0.80      0.76        61
#           53       0.00      0.00      0.00         4
#           54       0.78      0.88      0.83       215
#           55       1.00      0.57      0.73         7
#           56       1.00      0.50      0.67         6
#           57       1.00      0.38      0.56        13
#           58       0.00      0.00      0.00        12
#           59       0.50      0.46      0.48        26
#           60       1.00      0.11      0.20         9
#           61       0.73      0.67      0.70        60
#           62       0.67      0.33      0.44        18
#           63       0.71      0.56      0.63        84
#           64       0.56      0.42      0.48        24
#           65       1.00      1.00      1.00         7
#           66       0.76      0.74      0.75        35
#           67       0.52      0.69      0.60        77
#           68       0.67      0.71      0.69       235
#           69       0.00      0.00      0.00         1
#           70       0.62      0.59      0.61       151
#           71       0.60      0.30      0.40        10
#           72       0.00      0.00      0.00         5
#           73       0.78      0.89      0.83        93
#           74       0.44      0.29      0.35        14
#           75       0.92      0.92      0.92        24
#           76       1.00      0.45      0.62        11
#           77       0.92      0.90      0.91        49
#           78       0.44      0.44      0.44         9
#           79       0.00      0.00      0.00         3
#           80       0.91      0.56      0.69        18
#           81       0.00      0.00      0.00         1
#           82       0.78      0.93      0.85        15
#           83       0.50      0.17      0.25         6
#           84       0.72      0.64      0.68       209
#           85       0.75      0.83      0.79       104
#           86       0.62      0.64      0.63        53
#           87       0.00      0.00      0.00         1
#           88       0.95      1.00      0.97        19
#           89       1.00      1.00      1.00         7
#           90       0.72      0.88      0.79        33
#           91       0.72      0.75      0.74       104
#           92       0.00      0.00      0.00         1
#           93       0.59      0.46      0.51       138
#           94       0.00      0.00      0.00         4
#           95       0.77      0.85      0.80       933
#           96       0.67      0.67      0.67         9
#           97       0.36      0.35      0.36        23
#           98       0.82      0.65      0.73        49
#           99       0.00      0.00      0.00         7
#          100       0.79      0.52      0.63        21
#          101       0.73      0.44      0.55        36
#          102       0.00      0.00      0.00         2
#          103       0.85      0.73      0.79        30
#          104       1.00      0.17      0.29        12
#          105       0.29      0.57      0.38         7
#          106       0.00      0.00      0.00         7
#          107       0.86      0.88      0.87       812
#          108       0.83      0.92      0.87        63
#          109       1.00      0.86      0.92         7
#          110       0.75      1.00      0.86         3
#          111       0.76      0.76      0.76        55
#          112       0.70      0.51      0.59        45
#          113       1.00      0.11      0.19        19
#          114       0.80      0.57      0.67         7
#          115       0.77      0.87      0.82        95
#          116       0.00      0.00      0.00         6
#          117       0.64      0.75      0.69        56
#          118       0.75      0.81      0.78       130
#          119       0.71      0.70      0.70       233
#          120       0.55      0.68      0.61        80
#          121       0.00      0.00      0.00         2
#          122       1.00      1.00      1.00        11
#
#     accuracy                           0.71      8648
#    macro avg       0.58      0.50      0.52      8648
# weighted avg       0.71      0.71      0.70      8648

# %%
len(train_embeddings[0])
# Out:
# 384

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(train_embeddings, Y_train)

y_pred = rf.predict(test_embeddings)

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ",accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.5712303422756707
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.63      0.58        99
#            1       0.77      0.70      0.73       126
#            2       0.58      0.48      0.53       130
#            3       0.88      0.58      0.70        12
#            4       0.53      0.15      0.24       118
#            5       1.00      0.03      0.06        30
#            6       0.46      0.28      0.35       104
#            7       0.00      0.00      0.00         9
#            8       0.42      0.83      0.56       557
#            9       0.00      0.00      0.00        11
#           10       0.72      0.45      0.55       225
#           11       0.00      0.00      0.00         3
#           12       0.46      0.86      0.60       189
#           13       0.00      0.00      0.00        42
#           14       0.00      0.00      0.00         3
#           15       0.00      0.00      0.00         9
#           16       0.00      0.00      0.00         2
#           17       0.83      0.51      0.63        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.83      0.15      0.25        34
#           21       0.00      0.00      0.00         9
#           22       0.00      0.00      0.00        11
#           23       0.59      0.96      0.73       167
#           24       0.00      0.00      0.00         9
#           25       0.71      0.41      0.52        29
#           26       0.75      0.30      0.43        20
#           27       0.40      0.12      0.18       100
#           28       0.59      0.96      0.73       268
#           29       1.00      0.44      0.62        27
#           30       0.33      0.04      0.07        24
#           31       0.42      0.28      0.34       179
#           32       0.00      0.00      0.00        19
#           33       0.67      0.01      0.03       135
#           34       0.72      0.56      0.63       180
#           35       0.64      0.78      0.71        69
#           36       0.00      0.00      0.00         4
#           37       0.44      0.30      0.36        53
#           38       0.49      0.68      0.57        87
#           39       0.00      0.00      0.00         4
#           40       0.57      0.80      0.67       180
#           41       0.59      0.75      0.66       272
#           42       0.89      0.40      0.55        20
#           43       0.76      0.94      0.84        33
#           44       0.00      0.00      0.00         4
#           45       0.00      0.00      0.00         5
#           46       0.44      0.20      0.28        20
#           47       1.00      0.07      0.13        14
#           49       0.62      0.24      0.34        34
#           50       0.62      0.33      0.43        15
#           51       1.00      0.03      0.06       175
#           52       0.76      0.46      0.57        61
#           53       0.00      0.00      0.00         4
#           54       0.62      0.77      0.69       215
#           55       0.00      0.00      0.00         7
#           56       1.00      0.17      0.29         6
#           57       0.00      0.00      0.00        13
#           58       0.00      0.00      0.00        12
#           59       0.00      0.00      0.00        26
#           60       0.00      0.00      0.00         9
#           61       0.70      0.55      0.62        60
#           62       1.00      0.17      0.29        18
#           63       0.73      0.10      0.17        84
#           64       0.20      0.04      0.07        24
#           65       1.00      0.14      0.25         7
#           66       0.90      0.26      0.40        35
#           67       0.38      0.29      0.33        77
#           68       0.52      0.59      0.55       235
#           69       0.00      0.00      0.00         1
#           70       0.53      0.34      0.42       151
#           71       0.00      0.00      0.00        10
#           72       0.00      0.00      0.00         5
#           73       0.92      0.51      0.65        93
#           74       0.00      0.00      0.00        14
#           75       0.94      0.67      0.78        24
#           76       0.67      0.18      0.29        11
#           77       0.91      0.84      0.87        49
#           78       0.00      0.00      0.00         9
#           79       0.00      0.00      0.00         3
#           80       0.00      0.00      0.00        18
#           81       0.00      0.00      0.00         1
#           82       0.89      0.53      0.67        15
#           83       1.00      0.17      0.29         6
#           84       0.73      0.23      0.36       209
#           85       0.65      0.74      0.69       104
#           86       0.70      0.40      0.51        53
#           87       0.00      0.00      0.00         1
#           88       1.00      1.00      1.00        19
#           89       1.00      0.71      0.83         7
#           90       0.68      0.85      0.76        33
#           91       0.81      0.24      0.37       104
#           92       0.00      0.00      0.00         1
#           93       0.64      0.07      0.12       138
#           94       0.00      0.00      0.00         4
#           95       0.51      0.86      0.64       933
#           96       1.00      0.11      0.20         9
#           97       1.00      0.04      0.08        23
#           98       0.50      0.06      0.11        49
#           99       0.00      0.00      0.00         7
#          100       0.00      0.00      0.00        21
#          101       1.00      0.06      0.11        36
#          102       0.00      0.00      0.00         2
#          103       0.87      0.67      0.75        30
#          104       0.00      0.00      0.00        12
#          105       0.00      0.00      0.00         7
#          106       0.00      0.00      0.00         7
#          107       0.64      0.91      0.75       812
#          108       0.86      0.48      0.61        63
#          109       1.00      0.57      0.73         7
#          110       1.00      0.67      0.80         3
#          111       0.88      0.42      0.57        55
#          112       0.80      0.09      0.16        45
#          113       1.00      0.05      0.10        19
#          114       0.00      0.00      0.00         7
#          115       0.68      0.73      0.70        95
#          116       0.00      0.00      0.00         6
#          117       0.71      0.27      0.39        56
#          118       0.66      0.69      0.67       130
#          119       0.64      0.50      0.56       233
#          120       0.51      0.40      0.45        80
#          121       0.00      0.00      0.00         2
#          122       1.00      0.36      0.53        11
#
#     accuracy                           0.57      8648
#    macro avg       0.47      0.28      0.31      8648
# weighted avg       0.59      0.57      0.52      8648

# %% [markdown]
# ## Neural Network

# %%
import tensorflow as tf

input_dim = 384
num_classes = 123

model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(input_dim,)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               98560
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 123)               15867
#
# =================================================================
# Total params: 147323 (575.48 KB)
# Trainable params: 147323 (575.48 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
type(train_embeddings[0])
# Out:
# numpy.ndarray

# %%
Y_train = np.array(Y_train)

train_accuracy = []
train_loss = []

epochs = 10
for epoch in range(epochs):
    print(f"\nEpoch {epoch + 1}/{epochs}")
    history = model.fit(train_embeddings, Y_train, batch_size=16)
    train_loss.append(history.history['loss'][0])
    train_acc = history.history['accuracy'][0]
    train_accuracy.append(train_acc)
    print(f"Training Loss: {train_loss[-1]}, Training Accuracy: {train_acc}")
# Out:
# Epoch 1/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 0.8439 - accuracy: 0.7286
# Training Loss: 0.843936562538147, Training Accuracy: 0.7285777926445007
#
# Epoch 2/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 0.7938 - accuracy: 0.7402
# Training Loss: 0.7938205599784851, Training Accuracy: 0.7401815056800842
#
# Epoch 3/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 0.7597 - accuracy: 0.7476
# Training Loss: 0.7596914172172546, Training Accuracy: 0.7476445436477661
#
# Epoch 4/10
# 2521/2521 [==============================] - 8s 3ms/step - loss: 0.7342 - accuracy: 0.7531
# Training Loss: 0.7342419624328613, Training Accuracy: 0.753099262714386
#
# Epoch 5/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 0.6972 - accuracy: 0.7638
# Training Loss: 0.6971562504768372, Training Accuracy: 0.7638351917266846
#
# Epoch 6/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 0.6739 - accuracy: 0.7707
# Training Loss: 0.673864483833313, Training Accuracy: 0.7706535458564758
#
# Epoch 7/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 0.6445 - accuracy: 0.7776
# Training Loss: 0.6444944739341736, Training Accuracy: 0.7776455283164978
#
# Epoch 8/10
# 2521/2521 [==============================] - 8s 3ms/step - loss: 0.6291 - accuracy: 0.7822
# Training Loss: 0.6290903091430664, Training Accuracy: 0.7822076678276062
#
# Epoch 9/10
# 2521/2521 [==============================] - 8s 3ms/step - loss: 0.6052 - accuracy: 0.7876
# Training Loss: 0.6052244305610657, Training Accuracy: 0.7875880002975464
#
# Epoch 10/10
# 2521/2521 [==============================] - 8s 3ms/step - loss: 0.5861 - accuracy: 0.7974
# Training Loss: 0.5860788822174072, Training Accuracy: 0.7973817586898804

# %%
y_pred_prob = model.predict(test_embeddings)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 271/271 [==============================] - 0s 2ms/step

# %%
len(y_pred)
# Out:
# 8648

# %%
y_pred
# Out:
# array([ 51, 107,  68, ...,  84,  27,  64])

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.67368177613321
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.51      0.58        99
#            1       0.76      0.75      0.75       126
#            2       0.61      0.73      0.66       130
#            3       0.69      0.92      0.79        12
#            4       0.57      0.58      0.57       118
#            5       0.27      0.27      0.27        30
#            6       0.45      0.41      0.43       104
#            7       1.00      0.22      0.36         9
#            8       0.52      0.73      0.61       557
#            9       0.14      0.09      0.11        11
#           10       0.64      0.70      0.67       225
#           11       0.00      0.00      0.00         3
#           12       0.73      0.86      0.79       189
#           13       0.62      0.36      0.45        42
#           14       0.00      0.00      0.00         3
#           15       0.67      0.22      0.33         9
#           16       0.00      0.00      0.00         2
#           17       0.69      0.84      0.76        37
#           18       0.00      0.00      0.00         1
#           19       0.50      0.20      0.29         5
#           20       0.52      0.44      0.48        34
#           21       0.00      0.00      0.00         9
#           22       0.55      0.55      0.55        11
#           23       0.75      0.81      0.78       167
#           24       0.11      0.11      0.11         9
#           25       0.48      0.45      0.46        29
#           26       0.73      0.55      0.63        20
#           27       0.38      0.24      0.29       100
#           28       0.85      0.83      0.84       268
#           29       0.60      0.67      0.63        27
#           30       0.21      0.12      0.16        24
#           31       0.54      0.39      0.45       179
#           32       0.38      0.32      0.34        19
#           33       0.75      0.27      0.39       135
#           34       0.68      0.66      0.67       180
#           35       0.76      0.86      0.80        69
#           36       0.00      0.00      0.00         4
#           37       0.51      0.45      0.48        53
#           38       0.59      0.62      0.60        87
#           39       0.12      0.25      0.17         4
#           40       0.80      0.74      0.77       180
#           41       0.76      0.75      0.76       272
#           42       0.65      0.65      0.65        20
#           43       0.80      0.97      0.88        33
#           44       0.00      0.00      0.00         4
#           45       0.50      0.20      0.29         5
#           46       0.46      0.60      0.52        20
#           47       0.33      0.07      0.12        14
#           48       0.00      0.00      0.00         0
#           49       0.39      0.44      0.42        34
#           50       0.62      0.53      0.57        15
#           51       0.65      0.42      0.51       175
#           52       0.71      0.77      0.74        61
#           53       1.00      0.25      0.40         4
#           54       0.75      0.79      0.77       215
#           55       0.60      0.86      0.71         7
#           56       0.80      0.67      0.73         6
#           57       0.50      0.46      0.48        13
#           58       0.67      0.17      0.27        12
#           59       0.40      0.46      0.43        26
#           60       0.20      0.22      0.21         9
#           61       0.72      0.65      0.68        60
#           62       0.62      0.28      0.38        18
#           63       0.62      0.58      0.60        84
#           64       0.31      0.17      0.22        24
#           65       0.71      0.71      0.71         7
#           66       0.64      0.77      0.70        35
#           67       0.42      0.62      0.50        77
#           68       0.65      0.66      0.66       235
#           69       1.00      1.00      1.00         1
#           70       0.66      0.58      0.62       151
#           71       0.40      0.40      0.40        10
#           72       0.00      0.00      0.00         5
#           73       0.73      0.88      0.80        93
#           74       0.23      0.21      0.22        14
#           75       0.79      0.92      0.85        24
#           76       0.58      0.64      0.61        11
#           77       0.95      0.73      0.83        49
#           78       0.29      0.44      0.35         9
#           79       0.00      0.00      0.00         3
#           80       0.50      0.67      0.57        18
#           81       0.00      0.00      0.00         1
#           82       0.71      0.80      0.75        15
#           83       0.50      0.33      0.40         6
#           84       0.68      0.62      0.65       209
#           85       0.63      0.79      0.70       104
#           86       0.50      0.62      0.55        53
#           87       0.00      0.00      0.00         1
#           88       1.00      0.95      0.97        19
#           89       0.70      1.00      0.82         7
#           90       0.56      0.76      0.64        33
#           91       0.65      0.79      0.71       104
#           92       0.00      0.00      0.00         1
#           93       0.65      0.38      0.48       138
#           94       0.00      0.00      0.00         4
#           95       0.79      0.77      0.78       933
#           96       0.43      0.67      0.52         9
#           97       0.38      0.43      0.41        23
#           98       0.72      0.63      0.67        49
#           99       0.00      0.00      0.00         7
#          100       0.50      0.48      0.49        21
#          101       0.56      0.50      0.53        36
#          102       0.10      0.50      0.17         2
#          103       0.64      0.77      0.70        30
#          104       0.67      0.50      0.57        12
#          105       0.27      0.43      0.33         7
#          106       0.33      0.14      0.20         7
#          107       0.83      0.86      0.85       812
#          108       0.82      0.87      0.85        63
#          109       0.60      0.86      0.71         7
#          110       0.60      1.00      0.75         3
#          111       0.75      0.69      0.72        55
#          112       0.63      0.53      0.58        45
#          113       0.25      0.16      0.19        19
#          114       0.36      0.57      0.44         7
#          115       0.70      0.80      0.75        95
#          116       0.00      0.00      0.00         6
#          117       0.53      0.59      0.56        56
#          118       0.73      0.75      0.74       130
#          119       0.68      0.71      0.69       233
#          120       0.63      0.59      0.61        80
#          121       0.00      0.00      0.00         2
#          122       0.90      0.82      0.86        11
#
#     accuracy                           0.67      8648
#    macro avg       0.51      0.49      0.48      8648
# weighted avg       0.67      0.67      0.67      8648

# %%
## Model 2
input_dim = 384
num_classes = 123

# Define the model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Dense(128, activation='relu', input_shape=(input_dim,)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               49280
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 256)               33024
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 512)               131584
#
#  dropout_4 (Dropout)         (None, 512)               0
#
#  dense_6 (Dense)             (None, 123)               63099
#
# =================================================================
# Total params: 276987 (1.06 MB)
# Trainable params: 276987 (1.06 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(train_embeddings, Y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 1261/1261 [==============================] - 6s 4ms/step - loss: 1.9369 - accuracy: 0.4760
# Epoch 2/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.3494 - accuracy: 0.5933
# Epoch 3/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.2263 - accuracy: 0.6219
# Epoch 4/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.1407 - accuracy: 0.6421
# Epoch 5/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.0819 - accuracy: 0.6560
# Epoch 6/20
# 1261/1261 [==============================] - 4s 4ms/step - loss: 1.0361 - accuracy: 0.6681
# Epoch 7/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.9946 - accuracy: 0.6779
# Epoch 8/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.9579 - accuracy: 0.6902
# Epoch 9/20
# 1261/1261 [==============================] - 4s 4ms/step - loss: 0.9239 - accuracy: 0.6956
# Epoch 10/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.8971 - accuracy: 0.7032
# Epoch 11/20
# 1261/1261 [==============================] - 4s 4ms/step - loss: 0.8734 - accuracy: 0.7082
# Epoch 12/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.8559 - accuracy: 0.7134
# Epoch 13/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.8322 - accuracy: 0.7225
# Epoch 14/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.8124 - accuracy: 0.7259
# Epoch 15/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7980 - accuracy: 0.7331
# Epoch 16/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7818 - accuracy: 0.7344
# Epoch 17/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7692 - accuracy: 0.7394
# Epoch 18/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7544 - accuracy: 0.7432
# Epoch 19/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7344 - accuracy: 0.7473
# Epoch 20/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7254 - accuracy: 0.7496

# %%
y_pred_prob = model.predict(test_embeddings)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 271/271 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.6711378353376504
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.73      0.65        99
#            1       0.74      0.78      0.76       126
#            2       0.58      0.70      0.63       130
#            3       0.79      0.92      0.85        12
#            4       0.59      0.48      0.53       118
#            5       0.36      0.27      0.31        30
#            6       0.53      0.30      0.38       104
#            7       0.45      0.56      0.50         9
#            8       0.53      0.70      0.60       557
#            9       0.00      0.00      0.00        11
#           10       0.69      0.63      0.66       225
#           11       0.00      0.00      0.00         3
#           12       0.76      0.81      0.78       189
#           13       0.61      0.48      0.53        42
#           14       0.00      0.00      0.00         3
#           15       0.38      0.33      0.35         9
#           16       0.00      0.00      0.00         2
#           17       0.70      0.81      0.75        37
#           18       0.00      0.00      0.00         1
#           19       0.50      0.20      0.29         5
#           20       0.60      0.26      0.37        34
#           21       0.00      0.00      0.00         9
#           22       0.38      0.27      0.32        11
#           23       0.68      0.89      0.77       167
#           24       0.00      0.00      0.00         9
#           25       0.38      0.45      0.41        29
#           26       0.73      0.55      0.63        20
#           27       0.33      0.20      0.25       100
#           28       0.80      0.91      0.85       268
#           29       0.76      0.59      0.67        27
#           30       0.17      0.17      0.17        24
#           31       0.51      0.38      0.43       179
#           32       0.25      0.11      0.15        19
#           33       0.63      0.24      0.35       135
#           34       0.63      0.76      0.69       180
#           35       0.75      0.84      0.79        69
#           36       0.00      0.00      0.00         4
#           37       0.45      0.49      0.47        53
#           38       0.58      0.64      0.61        87
#           39       0.08      0.25      0.12         4
#           40       0.77      0.82      0.80       180
#           41       0.75      0.74      0.75       272
#           42       0.69      0.55      0.61        20
#           43       0.91      0.88      0.89        33
#           44       0.00      0.00      0.00         4
#           45       1.00      0.20      0.33         5
#           46       0.47      0.70      0.56        20
#           47       0.43      0.21      0.29        14
#           49       0.47      0.44      0.45        34
#           50       0.47      0.60      0.53        15
#           51       0.66      0.34      0.45       175
#           52       0.70      0.79      0.74        61
#           53       0.20      0.25      0.22         4
#           54       0.77      0.70      0.73       215
#           55       0.38      0.71      0.50         7
#           56       1.00      0.50      0.67         6
#           57       0.50      0.31      0.38        13
#           58       0.50      0.08      0.14        12
#           59       0.36      0.19      0.25        26
#           60       0.50      0.11      0.18         9
#           61       0.71      0.58      0.64        60
#           62       0.17      0.06      0.08        18
#           63       0.60      0.65      0.63        84
#           64       0.42      0.46      0.44        24
#           65       1.00      0.57      0.73         7
#           66       0.77      0.57      0.66        35
#           67       0.41      0.68      0.51        77
#           68       0.63      0.69      0.66       235
#           69       0.00      0.00      0.00         1
#           70       0.68      0.52      0.59       151
#           71       0.50      0.20      0.29        10
#           72       0.00      0.00      0.00         5
#           73       0.71      0.86      0.78        93
#           74       0.38      0.21      0.27        14
#           75       0.92      0.92      0.92        24
#           76       0.50      0.18      0.27        11
#           77       0.87      0.94      0.90        49
#           78       0.36      0.44      0.40         9
#           79       0.00      0.00      0.00         3
#           80       0.52      0.67      0.59        18
#           81       0.00      0.00      0.00         1
#           82       0.74      0.93      0.82        15
#           83       0.20      0.33      0.25         6
#           84       0.61      0.68      0.65       209
#           85       0.66      0.81      0.73       104
#           86       0.52      0.58      0.55        53
#           87       0.00      0.00      0.00         1
#           88       0.95      0.95      0.95        19
#           89       1.00      0.86      0.92         7
#           90       0.61      0.82      0.70        33
#           91       0.69      0.72      0.70       104
#           92       0.00      0.00      0.00         1
#           93       0.59      0.34      0.43       138
#           94       0.50      0.25      0.33         4
#           95       0.80      0.79      0.80       933
#           96       0.54      0.78      0.64         9
#           97       0.35      0.30      0.33        23
#           98       0.69      0.73      0.71        49
#           99       0.00      0.00      0.00         7
#          100       0.91      0.48      0.62        21
#          101       0.61      0.56      0.58        36
#          102       0.14      0.50      0.22         2
#          103       0.59      0.77      0.67        30
#          104       0.45      0.42      0.43        12
#          105       0.09      0.14      0.11         7
#          106       0.00      0.00      0.00         7
#          107       0.84      0.87      0.85       812
#          108       0.80      0.81      0.80        63
#          109       0.86      0.86      0.86         7
#          110       0.60      1.00      0.75         3
#          111       0.67      0.67      0.67        55
#          112       0.62      0.44      0.52        45
#          113       0.17      0.05      0.08        19
#          114       0.67      0.29      0.40         7
#          115       0.76      0.81      0.79        95
#          116       0.00      0.00      0.00         6
#          117       0.53      0.50      0.51        56
#          118       0.69      0.75      0.72       130
#          119       0.67      0.71      0.69       233
#          120       0.59      0.56      0.58        80
#          121       0.00      0.00      0.00         2
#          122       0.91      0.91      0.91        11
#
#     accuracy                           0.67      8648
#    macro avg       0.50      0.47      0.46      8648
# weighted avg       0.67      0.67      0.66      8648

# %%
## Model 3
model3 = tf.keras.Sequential([
    tf.keras.layers.Dense(512, activation='relu', input_shape=(input_dim,)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# Compile the model
model3.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model3.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 512)               197120
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_8 (Dense)             (None, 256)               131328
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 123)               15867
#
# =================================================================
# Total params: 377211 (1.44 MB)
# Trainable params: 377211 (1.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model3.fit(train_embeddings, Y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 1261/1261 [==============================] - 6s 4ms/step - loss: 1.8858 - accuracy: 0.4930
# Epoch 2/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.2928 - accuracy: 0.6114
# Epoch 3/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.1459 - accuracy: 0.6468
# Epoch 4/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.0435 - accuracy: 0.6710
# Epoch 5/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.9618 - accuracy: 0.6916
# Epoch 6/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.8878 - accuracy: 0.7127
# Epoch 7/20
# 1261/1261 [==============================] - 6s 4ms/step - loss: 0.8219 - accuracy: 0.7349
# Epoch 8/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7607 - accuracy: 0.7490
# Epoch 9/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7051 - accuracy: 0.7652
# Epoch 10/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.6559 - accuracy: 0.7793
# Epoch 11/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.6108 - accuracy: 0.7922
# Epoch 12/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.5713 - accuracy: 0.8049
# Epoch 13/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.5337 - accuracy: 0.8150
# Epoch 14/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.5077 - accuracy: 0.8241
# Epoch 15/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.4780 - accuracy: 0.8328
# Epoch 16/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.4491 - accuracy: 0.8408
# Epoch 17/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.4264 - accuracy: 0.8493
# Epoch 18/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.4099 - accuracy: 0.8552
# Epoch 19/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.3966 - accuracy: 0.8614
# Epoch 20/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.3751 - accuracy: 0.8662

# %%
y_pred_prob = model3.predict(test_embeddings)
y_pred = np.argmax(y_pred_prob, axis=1)

from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# 271/271 [==============================] - 1s 2ms/step
# Accuracy:  0.6667437557816837
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.62      0.64        99
#            1       0.70      0.82      0.75       126
#            2       0.71      0.59      0.65       130
#            3       0.65      0.92      0.76        12
#            4       0.50      0.53      0.51       118
#            5       0.33      0.27      0.30        30
#            6       0.47      0.45      0.46       104
#            7       0.62      0.56      0.59         9
#            8       0.55      0.55      0.55       557
#            9       0.67      0.18      0.29        11
#           10       0.63      0.65      0.64       225
#           11       0.00      0.00      0.00         3
#           12       0.78      0.82      0.80       189
#           13       0.67      0.33      0.44        42
#           14       0.00      0.00      0.00         3
#           15       0.50      0.56      0.53         9
#           16       0.33      0.50      0.40         2
#           17       0.67      0.70      0.68        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.45      0.41      0.43        34
#           21       0.22      0.22      0.22         9
#           22       0.43      0.55      0.48        11
#           23       0.73      0.87      0.79       167
#           24       0.07      0.11      0.09         9
#           25       0.45      0.48      0.47        29
#           26       0.75      0.60      0.67        20
#           27       0.39      0.24      0.30       100
#           28       0.81      0.83      0.82       268
#           29       0.76      0.70      0.73        27
#           30       0.11      0.17      0.14        24
#           31       0.42      0.42      0.42       179
#           32       0.27      0.21      0.24        19
#           33       0.58      0.32      0.41       135
#           34       0.64      0.74      0.68       180
#           35       0.76      0.83      0.79        69
#           36       0.00      0.00      0.00         4
#           37       0.59      0.42      0.49        53
#           38       0.50      0.66      0.56        87
#           39       0.20      0.25      0.22         4
#           40       0.77      0.83      0.80       180
#           41       0.70      0.80      0.75       272
#           42       0.81      0.65      0.72        20
#           43       0.79      0.94      0.86        33
#           44       0.00      0.00      0.00         4
#           45       0.25      0.20      0.22         5
#           46       0.46      0.80      0.58        20
#           47       0.29      0.14      0.19        14
#           49       0.33      0.32      0.33        34
#           50       0.69      0.60      0.64        15
#           51       0.58      0.62      0.60       175
#           52       0.68      0.85      0.76        61
#           53       1.00      0.25      0.40         4
#           54       0.74      0.81      0.77       215
#           55       1.00      0.57      0.73         7
#           56       1.00      0.83      0.91         6
#           57       0.62      0.38      0.48        13
#           58       0.33      0.17      0.22        12
#           59       0.39      0.50      0.44        26
#           60       0.50      0.22      0.31         9
#           61       0.72      0.63      0.67        60
#           62       0.44      0.39      0.41        18
#           63       0.60      0.57      0.59        84
#           64       0.53      0.33      0.41        24
#           65       1.00      0.57      0.73         7
#           66       0.76      0.71      0.74        35
#           67       0.55      0.48      0.51        77
#           68       0.55      0.69      0.61       235
#           69       0.00      0.00      0.00         1
#           70       0.61      0.50      0.55       151
#           71       0.50      0.30      0.37        10
#           72       0.00      0.00      0.00         5
#           73       0.74      0.82      0.78        93
#           74       0.38      0.21      0.27        14
#           75       0.88      0.92      0.90        24
#           76       0.71      0.45      0.56        11
#           77       0.88      0.92      0.90        49
#           78       0.38      0.56      0.45         9
#           79       0.00      0.00      0.00         3
#           80       0.58      0.39      0.47        18
#           81       0.00      0.00      0.00         1
#           82       0.75      0.80      0.77        15
#           83       0.40      0.33      0.36         6
#           84       0.70      0.59      0.64       209
#           85       0.67      0.78      0.72       104
#           86       0.50      0.58      0.54        53
#           87       0.00      0.00      0.00         1
#           88       0.90      1.00      0.95        19
#           89       0.86      0.86      0.86         7
#           90       0.68      0.79      0.73        33
#           91       0.72      0.76      0.74       104
#           92       0.00      0.00      0.00         1
#           93       0.50      0.63      0.56       138
#           94       0.00      0.00      0.00         4
#           95       0.80      0.76      0.78       933
#           96       0.42      0.56      0.48         9
#           97       0.40      0.26      0.32        23
#           98       0.71      0.73      0.72        49
#           99       0.00      0.00      0.00         7
#          100       0.56      0.48      0.51        21
#          101       0.62      0.56      0.59        36
#          102       0.07      0.50      0.12         2
#          103       0.74      0.67      0.70        30
#          104       0.60      0.25      0.35        12
#          105       0.20      0.57      0.30         7
#          106       0.00      0.00      0.00         7
#          107       0.84      0.82      0.83       812
#          108       0.77      0.79      0.78        63
#          109       0.75      0.86      0.80         7
#          110       0.50      1.00      0.67         3
#          111       0.76      0.76      0.76        55
#          112       0.48      0.29      0.36        45
#          113       0.30      0.16      0.21        19
#          114       0.38      0.43      0.40         7
#          115       0.77      0.85      0.81        95
#          116       0.00      0.00      0.00         6
#          117       0.63      0.57      0.60        56
#          118       0.72      0.70      0.71       130
#          119       0.65      0.75      0.70       233
#          120       0.54      0.42      0.48        80
#          121       0.00      0.00      0.00         2
#          122       1.00      0.82      0.90        11
#
#     accuracy                           0.67      8648
#    macro avg       0.51      0.49      0.49      8648
# weighted avg       0.67      0.67      0.66      8648

# %% [markdown]
# ## XGBOOST

# %%
import xgboost as xgb

dtrain = xgb.DMatrix(train_embeddings, label=Y_train)
dtest = xgb.DMatrix(test_embeddings, label=Y_test)

# Define XGBoost parameters
param = {
    'objective': 'multi:softmax',
    'num_class': 123,
    'max_depth': 6,
    'eta': 0.3,
    'eval_metric': 'merror'
}

# Train the XGBoost model
num_round = 100
bst = xgb.train(param, dtrain, num_round)

# Predict the labels of the test set
xg_y_pred = bst.predict(dtest)

# %%
xg_y_pred
# Out:
# array([ 51., 107.,  68., ...,  84.,  27.,  77.], dtype=float32)

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(xg_y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, xg_y_pred))
# Out:
# Accuracy:  0.5883441258094357
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.55      0.47      0.51        99
#            1       0.65      0.67      0.66       126
#            2       0.59      0.55      0.57       130
#            3       0.82      0.75      0.78        12
#            4       0.44      0.39      0.41       118
#            5       0.20      0.13      0.16        30
#            6       0.36      0.35      0.35       104
#            7       0.60      0.33      0.43         9
#            8       0.47      0.60      0.52       557
#            9       0.25      0.09      0.13        11
#           10       0.56      0.49      0.52       225
#           11       0.50      0.33      0.40         3
#           12       0.63      0.79      0.70       189
#           13       0.47      0.19      0.27        42
#           14       0.00      0.00      0.00         3
#           15       0.38      0.33      0.35         9
#           16       0.00      0.00      0.00         2
#           17       0.72      0.62      0.67        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.48      0.32      0.39        34
#           21       0.00      0.00      0.00         9
#           22       0.71      0.45      0.56        11
#           23       0.64      0.74      0.68       167
#           24       0.00      0.00      0.00         9
#           25       0.52      0.41      0.46        29
#           26       0.63      0.60      0.62        20
#           27       0.31      0.21      0.25       100
#           28       0.76      0.81      0.78       268
#           29       0.61      0.52      0.56        27
#           30       0.32      0.38      0.35        24
#           31       0.39      0.35      0.37       179
#           32       0.50      0.26      0.34        19
#           33       0.45      0.27      0.34       135
#           34       0.53      0.54      0.54       180
#           35       0.71      0.77      0.74        69
#           36       0.00      0.00      0.00         4
#           37       0.48      0.40      0.43        53
#           38       0.50      0.60      0.54        87
#           39       0.14      0.25      0.18         4
#           40       0.68      0.72      0.70       180
#           41       0.65      0.65      0.65       272
#           42       0.91      0.50      0.65        20
#           43       0.79      0.91      0.85        33
#           44       0.00      0.00      0.00         4
#           45       0.00      0.00      0.00         5
#           46       0.53      0.50      0.51        20
#           47       0.50      0.14      0.22        14
#           49       0.59      0.38      0.46        34
#           50       0.50      0.53      0.52        15
#           51       0.50      0.33      0.40       175
#           52       0.65      0.54      0.59        61
#           53       0.33      0.25      0.29         4
#           54       0.61      0.66      0.64       215
#           55       0.33      0.29      0.31         7
#           56       1.00      0.33      0.50         6
#           57       0.75      0.46      0.57        13
#           58       0.00      0.00      0.00        12
#           59       0.29      0.31      0.30        26
#           60       0.33      0.11      0.17         9
#           61       0.60      0.62      0.61        60
#           62       0.43      0.33      0.38        18
#           63       0.62      0.43      0.51        84
#           64       0.47      0.33      0.39        24
#           65       1.00      0.29      0.44         7
#           66       0.77      0.69      0.73        35
#           67       0.45      0.60      0.51        77
#           68       0.52      0.57      0.54       235
#           69       0.00      0.00      0.00         1
#           70       0.39      0.43      0.41       151
#           71       0.25      0.10      0.14        10
#           72       0.00      0.00      0.00         5
#           73       0.73      0.71      0.72        93
#           74       0.50      0.14      0.22        14
#           75       0.78      0.58      0.67        24
#           76       1.00      0.36      0.53        11
#           77       0.88      0.78      0.83        49
#           78       0.29      0.22      0.25         9
#           79       0.00      0.00      0.00         3
#           80       0.88      0.39      0.54        18
#           81       0.00      0.00      0.00         1
#           82       0.77      0.67      0.71        15
#           83       0.50      0.17      0.25         6
#           84       0.58      0.43      0.49       209
#           85       0.70      0.76      0.73       104
#           86       0.55      0.55      0.55        53
#           87       0.00      0.00      0.00         1
#           88       1.00      0.84      0.91        19
#           89       0.86      0.86      0.86         7
#           90       0.69      0.82      0.75        33
#           91       0.67      0.63      0.65       104
#           92       0.00      0.00      0.00         1
#           93       0.50      0.43      0.46       138
#           94       0.00      0.00      0.00         4
#           95       0.61      0.77      0.68       933
#           96       0.75      0.67      0.71         9
#           97       0.20      0.09      0.12        23
#           98       0.73      0.45      0.56        49
#           99       0.00      0.00      0.00         7
#          100       0.78      0.33      0.47        21
#          101       0.40      0.22      0.29        36
#          102       0.00      0.00      0.00         2
#          103       0.68      0.63      0.66        30
#          104       1.00      0.25      0.40        12
#          105       0.29      0.29      0.29         7
#          106       0.00      0.00      0.00         7
#          107       0.73      0.79      0.76       812
#          108       0.71      0.73      0.72        63
#          109       0.86      0.86      0.86         7
#          110       0.67      0.67      0.67         3
#          111       0.70      0.60      0.65        55
#          112       0.53      0.47      0.49        45
#          113       0.88      0.37      0.52        19
#          114       0.25      0.14      0.18         7
#          115       0.73      0.72      0.72        95
#          116       0.00      0.00      0.00         6
#          117       0.44      0.46      0.45        56
#          118       0.60      0.68      0.64       130
#          119       0.56      0.56      0.56       233
#          120       0.37      0.39      0.38        80
#          121       0.00      0.00      0.00         2
#          122       1.00      0.82      0.90        11
#
#     accuracy                           0.59      8648
#    macro avg       0.48      0.40      0.42      8648
# weighted avg       0.58      0.59      0.58      8648

# %%
## final model
from sklearn.svm import SVC
svm = SVC()

svm.fit(train_embeddings,Y_train)
y_pred = svm.predict(test_embeddings)

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.7119565217391305
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.73      0.72        99
#            1       0.80      0.80      0.80       126
#            2       0.64      0.70      0.67       130
#            3       0.86      1.00      0.92        12
#            4       0.62      0.52      0.56       118
#            5       0.43      0.20      0.27        30
#            6       0.61      0.50      0.55       104
#            7       0.71      0.56      0.63         9
#            8       0.52      0.71      0.60       557
#            9       0.60      0.27      0.37        11
#           10       0.68      0.68      0.68       225
#           11       0.00      0.00      0.00         3
#           12       0.70      0.92      0.80       189
#           13       0.70      0.33      0.45        42
#           14       0.00      0.00      0.00         3
#           15       0.83      0.56      0.67         9
#           16       0.00      0.00      0.00         2
#           17       0.78      0.78      0.78        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.81      0.38      0.52        34
#           21       0.00      0.00      0.00         9
#           22       0.67      0.55      0.60        11
#           23       0.71      0.93      0.81       167
#           24       0.00      0.00      0.00         9
#           25       0.73      0.55      0.63        29
#           26       0.70      0.70      0.70        20
#           27       0.40      0.23      0.29       100
#           28       0.82      0.95      0.88       268
#           29       0.95      0.67      0.78        27
#           30       0.32      0.29      0.30        24
#           31       0.54      0.43      0.48       179
#           32       0.50      0.21      0.30        19
#           33       0.78      0.30      0.43       135
#           34       0.67      0.77      0.72       180
#           35       0.81      0.90      0.85        69
#           36       0.00      0.00      0.00         4
#           37       0.53      0.58      0.55        53
#           38       0.57      0.75      0.65        87
#           39       0.25      0.25      0.25         4
#           40       0.79      0.81      0.80       180
#           41       0.78      0.77      0.78       272
#           42       1.00      0.55      0.71        20
#           43       0.86      0.94      0.90        33
#           44       0.00      0.00      0.00         4
#           45       0.00      0.00      0.00         5
#           46       0.48      0.75      0.59        20
#           47       0.67      0.14      0.24        14
#           49       0.54      0.41      0.47        34
#           50       0.79      0.73      0.76        15
#           51       0.75      0.41      0.53       175
#           52       0.72      0.80      0.76        61
#           53       0.00      0.00      0.00         4
#           54       0.78      0.88      0.83       215
#           55       1.00      0.57      0.73         7
#           56       1.00      0.50      0.67         6
#           57       1.00      0.38      0.56        13
#           58       0.00      0.00      0.00        12
#           59       0.50      0.46      0.48        26
#           60       1.00      0.11      0.20         9
#           61       0.73      0.67      0.70        60
#           62       0.67      0.33      0.44        18
#           63       0.71      0.56      0.63        84
#           64       0.56      0.42      0.48        24
#           65       1.00      1.00      1.00         7
#           66       0.76      0.74      0.75        35
#           67       0.52      0.69      0.60        77
#           68       0.67      0.71      0.69       235
#           69       0.00      0.00      0.00         1
#           70       0.62      0.59      0.61       151
#           71       0.60      0.30      0.40        10
#           72       0.00      0.00      0.00         5
#           73       0.78      0.89      0.83        93
#           74       0.44      0.29      0.35        14
#           75       0.92      0.92      0.92        24
#           76       1.00      0.45      0.62        11
#           77       0.92      0.90      0.91        49
#           78       0.44      0.44      0.44         9
#           79       0.00      0.00      0.00         3
#           80       0.91      0.56      0.69        18
#           81       0.00      0.00      0.00         1
#           82       0.78      0.93      0.85        15
#           83       0.50      0.17      0.25         6
#           84       0.72      0.64      0.68       209
#           85       0.75      0.83      0.79       104
#           86       0.62      0.64      0.63        53
#           87       0.00      0.00      0.00         1
#           88       0.95      1.00      0.97        19
#           89       1.00      1.00      1.00         7
#           90       0.72      0.88      0.79        33
#           91       0.72      0.75      0.74       104
#           92       0.00      0.00      0.00         1
#           93       0.59      0.46      0.51       138
#           94       0.00      0.00      0.00         4
#           95       0.77      0.85      0.80       933
#           96       0.67      0.67      0.67         9
#           97       0.36      0.35      0.36        23
#           98       0.82      0.65      0.73        49
#           99       0.00      0.00      0.00         7
#          100       0.79      0.52      0.63        21
#          101       0.73      0.44      0.55        36
#          102       0.00      0.00      0.00         2
#          103       0.85      0.73      0.79        30
#          104       1.00      0.17      0.29        12
#          105       0.29      0.57      0.38         7
#          106       0.00      0.00      0.00         7
#          107       0.86      0.88      0.87       812
#          108       0.83      0.92      0.87        63
#          109       1.00      0.86      0.92         7
#          110       0.75      1.00      0.86         3
#          111       0.76      0.76      0.76        55
#          112       0.70      0.51      0.59        45
#          113       1.00      0.11      0.19        19
#          114       0.80      0.57      0.67         7
#          115       0.77      0.87      0.82        95
#          116       0.00      0.00      0.00         6
#          117       0.64      0.75      0.69        56
#          118       0.75      0.81      0.78       130
#          119       0.71      0.70      0.70       233
#          120       0.55      0.68      0.61        80
#          121       0.00      0.00      0.00         2
#          122       1.00      1.00      1.00        11
#
#     accuracy                           0.71      8648
#    macro avg       0.58      0.50      0.52      8648
# weighted avg       0.71      0.71      0.70      8648

# %%
final_model = svm

# %%
test_df = pd.read_csv("/content/forcI_test_no_labels.csv")
test_df
# Out:
#                                                abstract  \
# 0     the paper introduces the notion of a locally c...
# 1     a bipartite state which is secretly chosen fro...
# 2     this short paper addresses the open problems l...
# 3     we find the symmetry algebras of cosets which ...
# 4     we present the results of the analysis of the ...
# ...                                                 ...
# 8898  background studies show that the u.s. foreign-...
# 8899  we prove uniqueness for the vortex-wave system...
# 8900  we demonstrate sensitivity of the mn 3d valenc...
# 8901  the coexisting regime of spin density wave (sd...
# 8902  software security is becoming a high priority ...
#
#                                                  author  \
# 0                                     Bartosz Zielinski
# 1           Yangjia Li, Runyao Duan, and Mingsheng Ying
# 2                        F\'elix Bou and Carles Noguera
# 3                         Dushyant Kumar, Menika Sharma
# 4     E. Jimenez-Bailon (Universita Roma Tre), M. Sa...
# ...                                                 ...
# 8898  ['James W. Vaupel', 'Danan Gu', 'Matthew E. Du...
# 8899       Christophe Lacave (ICJ), Evelyne Miot (LJLL)
# 8900  K. W. Edmonds, G. van der Laan, N. R. S. Farle...
# 8901  Q. Q. Ge, Z. R. Ye, M. Xu, Y. Zhang, J. Jiang,...
# 8902  David N. Palacio, Daniel McCrystal, Kevin Mora...
#
#                                doi  url  publication month  publication year  \
# 0                              NaN  NaN                NaN               NaN
# 1       10.1103/PhysRevA.82.032339  NaN                NaN               NaN
# 2                              NaN  NaN                NaN               NaN
# 3          10.1007/JHEP08(2019)179  NaN                NaN               NaN
# 4       10.1051/0004-6361:20065566  NaN                NaN               NaN
# ...                            ...  ...                ...               ...
# 8898  10.1371/journal.pone.0037177  NaN                5.0            2012.0
# 8899                           NaN  NaN                NaN               NaN
# 8900    10.1103/PhysRevB.77.113205  NaN                NaN               NaN
# 8901     10.1103/PhysRevX.3.011020  NaN                NaN               NaN
# 8902                           NaN  NaN                NaN               NaN
#
#                                                   title  \
# 0                   Locally coalgebra-Galois extensions
# 1     Local Unambiguous Discrimination with Remainin...
# 2     Solution of some problems in the arithmetical ...
# 3                   Symmetry Algebras of Stringy Cosets
# 4     XMM-Newton view of the double-peaked Fe K-alph...
# ...                                                 ...
# 8898  survival differences among native-born and for...
# 8899  Uniqueness for the vortex-wave system when the...
# 8900  Strain dependence of the Mn anisotropy in ferr...
# 8901  Anisotropic but nodeless superconducting gap i...
# 8902  Learning to Identify Security-Related Issues U...
#
#                           publisher  data_index
# 0                               NaN       22901
# 1                               NaN       47248
# 2                               NaN       27601
# 3                               NaN       36511
# 4                               NaN       15483
# ...                             ...         ...
# 8898                       PLoS ONE       43679
# 8899                            NaN       41425
# 8900                            NaN       46483
# 8901  Phys. Rev. X 3, 011020 (2013)       53461
# 8902                            NaN       30020
#
# [8903 rows x 9 columns]

# %%
test_df.drop(['doi','url','publication month', 'publication year','publisher', 'author'], axis =1 , inplace = True)
test_df.fillna('', inplace=True)
test_df['text'] = test_df['title'] + test_df['abstract']
test_df['text'] = NLP_cleaning(test_df.text.values.tolist())
test_df = test_df[['text', 'data_index']]
test_df
# Out:
# Cleaning: 100%|██████████| 8903/8903 [00:00<00:00, 21409.98it/s]
#                                                    text  data_index
# 0     locally coalgebra galois extensionsthe paper i...       22901
# 1     local unambiguous discrimination with remainin...       47248
# 2     solution of some problems in the arithmetical ...       27601
# 3     symmetry algebras of stringy cosetswe find the...       36511
# 4     xmm newton view of the double peaked fe k alph...       15483
# ...                                                 ...         ...
# 8898  survival differences among native born and for...       43679
# 8899  uniqueness for the vortex wave system when the...       41425
# 8900  strain dependence of the mn anisotropy in ferr...       46483
# 8901  anisotropic but nodeless superconducting gap i...       53461
# 8902  learning to identify security related issues u...       30020
#
# [8903 rows x 2 columns]

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
input = test_df['text'].tolist()
input = model.encode(input)

# %%
preds = final_model.predict(input)

# %%
preds
# Out:
# array([  0, 107, 120, ...,  68,  73,  35])

# %%
preds = label_encoder.inverse_transform(preds)

# %%
submission = pd.DataFrame()
submission['data_index'] = test_df['data_index']
submission['target'] = preds
submission
# Out:
#       data_index                             target
# 0          22901                            Algebra
# 1          47248                    Quantum Physics
# 2          27601                  Theory/Algorithms
# 3          36511                    Quantum Physics
# 4          15483         Astrophysics and Astronomy
# ...          ...                                ...
# 8898       43679                     Bioinformatics
# 8899       41425         Dynamics/Dynamical Systems
# 8900       46483  Materials Science and Engineering
# 8901       53461             Mechanics of Materials
# 8902       30020          Cryptography and Security
#
# [8903 rows x 2 columns]

# %%
import zipfile
submission.to_csv('predictions.csv')
zipfile.ZipFile('predictions.zip', mode='w').write("predictions.csv")

# %%
tt = pd.read_csv("/content/forcI_test_no_labels.csv")
tt
# Out:
#                                                abstract  \
# 0     the paper introduces the notion of a locally c...
# 1     a bipartite state which is secretly chosen fro...
# 2     this short paper addresses the open problems l...
# 3     we find the symmetry algebras of cosets which ...
# 4     we present the results of the analysis of the ...
# ...                                                 ...
# 8898  background studies show that the u.s. foreign-...
# 8899  we prove uniqueness for the vortex-wave system...
# 8900  we demonstrate sensitivity of the mn 3d valenc...
# 8901  the coexisting regime of spin density wave (sd...
# 8902  software security is becoming a high priority ...
#
#                                                  author  \
# 0                                     Bartosz Zielinski
# 1           Yangjia Li, Runyao Duan, and Mingsheng Ying
# 2                        F\'elix Bou and Carles Noguera
# 3                         Dushyant Kumar, Menika Sharma
# 4     E. Jimenez-Bailon (Universita Roma Tre), M. Sa...
# ...                                                 ...
# 8898  ['James W. Vaupel', 'Danan Gu', 'Matthew E. Du...
# 8899       Christophe Lacave (ICJ), Evelyne Miot (LJLL)
# 8900  K. W. Edmonds, G. van der Laan, N. R. S. Farle...
# 8901  Q. Q. Ge, Z. R. Ye, M. Xu, Y. Zhang, J. Jiang,...
# 8902  David N. Palacio, Daniel McCrystal, Kevin Mora...
#
#                                doi  url  publication month  publication year  \
# 0                              NaN  NaN                NaN               NaN
# 1       10.1103/PhysRevA.82.032339  NaN                NaN               NaN
# 2                              NaN  NaN                NaN               NaN
# 3          10.1007/JHEP08(2019)179  NaN                NaN               NaN
# 4       10.1051/0004-6361:20065566  NaN                NaN               NaN
# ...                            ...  ...                ...               ...
# 8898  10.1371/journal.pone.0037177  NaN                5.0            2012.0
# 8899                           NaN  NaN                NaN               NaN
# 8900    10.1103/PhysRevB.77.113205  NaN                NaN               NaN
# 8901     10.1103/PhysRevX.3.011020  NaN                NaN               NaN
# 8902                           NaN  NaN                NaN               NaN
#
#                                                   title  \
# 0                   Locally coalgebra-Galois extensions
# 1     Local Unambiguous Discrimination with Remainin...
# 2     Solution of some problems in the arithmetical ...
# 3                   Symmetry Algebras of Stringy Cosets
# 4     XMM-Newton view of the double-peaked Fe K-alph...
# ...                                                 ...
# 8898  survival differences among native-born and for...
# 8899  Uniqueness for the vortex-wave system when the...
# 8900  Strain dependence of the Mn anisotropy in ferr...
# 8901  Anisotropic but nodeless superconducting gap i...
# 8902  Learning to Identify Security-Related Issues U...
#
#                           publisher  data_index
# 0                               NaN       22901
# 1                               NaN       47248
# 2                               NaN       27601
# 3                               NaN       36511
# 4                               NaN       15483
# ...                             ...         ...
# 8898                       PLoS ONE       43679
# 8899                            NaN       41425
# 8900                            NaN       46483
# 8901  Phys. Rev. X 3, 011020 (2013)       53461
# 8902                            NaN       30020
#
# [8903 rows x 9 columns]

# %%
tt.drop(['doi','url','publication month', 'publication year','publisher', 'author'], axis =1 , inplace = True)
rows_with_null = tt[tt.isnull().any(axis=1)]
rows_with_null
# Out:
#      abstract                                              title  data_index
# 58        NaN  realized vs apparent reduction in enemies of t...       11400
# 132       NaN  open access papers: their growth over time and...       40326
# 141       NaN      general-purpose question-answering with macaw       19412
# 208       NaN  inhibition between invasives: a newly introduc...        7509
# 214       NaN  impact of nb(v) substitution on the structure ...       18447
# ...       ...                                                ...         ...
# 8739      NaN  emergency response information systems: emergi...        2519
# 8781      NaN                                    cloud computing       17405
# 8818      NaN  an improved decision support system for detect...       48096
# 8856      NaN  sustainable forest management in sardegna: fro...       52861
# 8867      NaN  formation of silicon by electrodeoxidation, an...       55925
#
# [255 rows x 3 columns]

# %%
li = rows_with_null['title']
li = li.to_list()
li
# Out:
# ['realized vs apparent reduction in enemies of the european starling',
#  'open access papers: their growth over time and from different countries, and their citations',
#  'general-purpose question-answering with macaw',
#  'inhibition between invasives: a newly introduced predator moderates the impacts of a previously established invasive predator',
#  'impact of nb(v) substitution on the structure and optical and photoelectrochemical properties of the cu5(ta1−xnbx)11o30 solid solution',
#  'occupancy anticipation for efficient exploration and navigation',
#  'strengthening the implementation of town planning laws and property management: panacea for reducing incidence of building collapse in nigeria',
#  'n‐decyloleat [mak value documentation in german language, 2019]',
#  'a single ectomycorrhizal fungal species can enable a pinus invasion',
#  'cryptic seedling herbivory by nocturnal introduced generalists impacts survival, performance of native and exotic plants',
#  '1,4-dioxane. mak value documentation, supplement – translation of the german version from 2019 – erratum',
#  'selenium – method for the determination of selenium and its inorganic compounds in workplace air using atomic absorption spectroscopy (aas). air monitoring method – translation of the german version from 2019',
#  'reasoning about object affordances in a knowledge base representation',
#  'can greek cities be smart?',
#  'parasitization of invasive gobiids in the eastern part of the central trans-european corridor of invasion of ponto-caspian hydrobionts',
#  'biodiversity and invasibility in grassland microcosms',
#  'a hybrid electromagnetism algorithm for multi-depot periodic vehicle routing problem',
#  'range expansion of agrilus convexicollis in european russia expedited by the invasion of the emerald ash borer, agrilus planipennis (coleoptera: buprestidae)',
#  'r3f: rdf triple filtering method for efficient sparql query processing',
#  'chang’e-4 initial spectroscopic identification of lunar far-side mantle-derived materials',
#  'open access initiatives in european universities: analysis of their implementation and the visibility of publications in the yerun network',
#  'status of campylobacter isolated in toyama prefecture',
#  'web 2.0: how social media applications leverage nonprofit responsesduring a wildfire crisis',
#  'coconut oil. mak value documentation – translation of the german version from 2019',
#  'lead and its compounds (except lead arsenate, lead chromate and alkyl lead compounds) – addendum for re-evaluation of the bar. assessment values in biological material – translation of the german version from 2020',
#  'an early detection of low rate ddos attack to sdn based data center networks using information distance metrics',
#  'patterns of success in passeriform bird introductions on saint helena',
#  'cluster analysis and classification of named entities.',
#  'evaluation of the early warning, alert and response system after cyclone winston, fiji, 2016',
#  'longformer: the long-document transformer',
#  'learning-based named entity recognition for morphologically-rich, resource-scarce languages',
#  'surveillance and seroepidemiology',
#  'scalable clustering methods for the name disambiguation problem',
#  'international phyical performance test profile (ipptp)',
#  'rewordqald9: a bilingual benchmark with alternative rewordings of qald questions',
#  'system and method to diffuse denial-of-service attacks using virtual machines',
#  'toward intelligent thessaloniki: from an agglomeration of apps to smart districts',
#  'a european framework for e-government competences',
#  'influence of two exotic earthworm species with different foraging strategies on abundance and composition of boreal microarthropods',
#  'polyethylenglykole (peg) (mittlere molmasse 200–600) [mak value documentation in german language, 2019]',
#  'origin, local experience, and the impact of biotic interactions on native and introduced senecio species',
#  'a robust optimization model for agile and build-to-order supply chain planning under uncertainties',
#  'vinylchlorid [mak value documentation in german language, 2019]',
#  'soft layer-specific multi-task summarization with entailment and question generation',
#  'cost of not having fair research data: cost-benefit analysis for fair research data',
#  'detection of campylobacter in meats and survival of campylobacter at low temperature. annual report of miyagi prefectural institute of public health and environment',
#  'dna barcodes for the northern european tachinid flies (diptera: tachinidae)',
#  'a mediator-free self-powered glucose biosensor based on a hybrid glucose/mno2 enzymatic biofuel cell',
#  'documentation process maturity model',
#  'the introduction of littorina littorea to british columbia, canada: potential impacts and the importance of biotic resistance by native predators',
#  'a modified densenet approach with nearmiss for anomaly detection in industrial control systems',
#  'ethylenoxid [mak value documentation in german language, 2019]',
#  'non-native earthworms promote plant invasion by ingesting seeds and modifying soil properties',
#  'p120 combined eeg/meg targeting and multi-electrode individually optimized tdcs stimulation of the human somatosensory network',
#  'n-vinyl-2-pyrrolidone [mak value documentation, 2014]',
#  'abnormalities of chromosome no. 1 related to blood dyscrasias: study of 10 cases',
#  'optic neuritis: findings on mri, csf examination and hla class ii typing in 60 patients and results of a short-term follow-up',
#  'citric acid – method for the determination of citric acid in workplace air using high performance liquid chromatography (hplc). airmonitoring method – translationof the german version from 2019',
#  'the richfields framework for semantic interoperability of food information across heterogenous information systems:',
#  'exploiting category-specific information for multi-document summarization',
#  'employee psychological well-being during the covid-19 pandemic in germany: a longitudinal study of demands, resources, and exhaustion',
#  'do rabbits eat voles? apparent competition, habitat heterogeneity and large-scale coexistence under mink predation',
#  'sars-cov-2 viral loads and serum iga/igg immune responses in critically ill covid-19 patients',
#  'limsi participation at qald-5@clef',
#  'transformer-based language model fine-tuning methods for covid-19 fake news detection',
#  'araucaria forest conservation: mechanisms providing resistance to invasion by exotic timber trees',
#  'the effect of thermotherapy using magnetic nanoparticles on rat malignant glioma',
#  'knowtator: a protégé plug-in for annotated corpus construction',
#  'species interactions contribute to the success of a global plant invader',
#  'a multi-label ensemble predicting model to service recommendation from social media contents',
#  'electronic health record-based detection of risk factors for clostridium difficile infection relapse',
#  'pattern-based acquisition of scientific entities from scholarly article titles',
#  'bacterial growth and primary production along a north-south transect of the atlantic ocean',
#  'proactive and reactive e-government services recommendation',
#  'biotic barriers to plant naturalization',
#  'factors associated with open access publishing costs in oncology journals',
#  'developing global public servants for good governance and sustainable development',
#  'clostridium difficile enteritis. a cause of intramural gas',
#  'the incidence of, and returns to overeducation in the uk',
#  'enriching a motion database by analogous combination of partial human motions',
#  'effects of open access and articles-in-press mechanisms on publishing lag and first-citation speed: a case on energy and fuels journals',
#  'solid proof of concept in an enterprise loan request use case',
#  'lipid-based nanoparticles as drug delivery system for paclitaxel in breast cancer treatment',
#  'ontologies supporting research-related information foraging using knowledge graphs: literature survey and holistic model mapping',
#  'invasion resistance, species buildup and community collapse in metapopulation models with interspecies competition',
#  'knowledge graphs on the web – an overview',
#  'does time since introduction influence enemy release of an invasive weed?',
#  'named entity recognition for ukrainian: a resource-light approach',
#  'biological pollution in the mediterranean sea: invasive versus introduced macrophytes',
#  'biological n2 fixation in the upwelling region off nw iberia: magnitude, relevance, and players',
#  'haemopoietic effects of ethanolic extract of stellaria media (l.) leaves on albino mice',
#  'ontonotes release 5.0 ldc2013t19',
#  'oblivious {multi-party} machine learning on trusted processors',
#  'experiments in single and multi-document summarization using mead',
#  'arbuscular mycorrhizal fungi (amf) as buffer for heavy metals phytoextraction by cucurbita maxima duch. grown on crude oil contaminated soil.',
#  'services: finance, trade and tourism',
#  'comparative analysis of mineral mapping for hyperspectraland multispectral imagery',
#  'joint parsing and generation for ive summarization',
#  "citizens' adaptive or avoiding behavioral response to an emergency message on their mobile phone",
#  'a cloud computing based network monitoring and threat detection system for critical infrastructures',
#  'factors impacting the intention to use emergency notification services in campus emergencies: an empirical investigationnotification services in campus emergencies: an empirical investigation',
#  'infection of human sweat glands by sars-cov-2',
#  'variable effects of large mammal herbivory on three non-native versus three native woody plants',
#  'invasive plants and their escape from root herbivory: a worldwide comparison of the root-feeding nematode communities of the dune grass ammophila arenaria in natural and introduced ranges',
#  'liquids production from coal and coal þ biomass with co2 capture and alternative storage options: aquifer co2 storage vs. co2-enhanced oil recovery',
#  'community structure, succession and invasibility in a seasonal deciduous forest in southern brazil',
#  'yellow crazy ant (anoplolepis gracilipes) invasions within undisturbed mainland australian habitats: no support for biotic resistance hypothesis',
#  'calciumbis(dinonylnaphthalinsulfonat) [mak value documentation in german language, 2018]',
#  'digital curation in libraries: an innovative way of content preservation and dissemination',
#  "university use of social media and the crisis lifecycle: organizational messages, first information responders' reactions, reframed messages and dissemination patterns.”",
#  'sound emissions from a plug-in electric vehicle',
#  'control with unknown time-varying cost functions',
#  'design/economics of a once-through natural gas fischeretropsch plant with power co-production',
#  'concurrent validity of social subtype and iq after early intensive behavioral intervention in children with autism: a preliminary investigation',
#  'cats a topic-oriented multi-document summarization system at duc 2005',
#  'a controlled experiment comparing the maintainability of programs designed with and without design patterns—a replication in a real programming environment',
#  'protection of personal data rights and obligations of the employees in the context of the health crisis caused by the covid 19 pandemic;978-606-39-0907-8',
#  'cost and performance baseline for fossil energy plants',
#  'a multi-method psychometric assessment of the affinity for technology interaction (ati) scale',
#  'ontonotes: a large training corpus for enhanced processing',
#  'paris agreement compatible (pac) energy scenario',
#  'identity-based proofs of storage with enhanced privacy',
#  'sime4kg: explainable distributed in-memory multi modal semantic similarity estimation for knowledge graphs',
#  'plant-based food resources, trophic interactions among alien species, and the abundance of na invasive ant',
#  'effects of human population, area, and time on non-native plant and fish diversity in the united states',
#  'network analysis and indicators',
#  'only automated surveillance with 100% sensitivity can save icps’ time',
#  'plantation of coniferous trees modifies risk and size of padus serotina borkh. invasion - evidence form a rogów arboretum case study',
#  'does online availability increase citations? theory and evidence from a panel of economics and business journals',
#  'the 37 combinatorial types of minimal, non-transitive, equivariant tilings of the euclidean plane',
#  'all crises opportunities? a comparison of how corporate and government organizations responded to the 2009 flu pandemic.”',
#  'pseudomembranous enteritis associated with clostridium difficile',
#  'release of invasive plants from fungal and viral pathogens',
#  'critical factors affecting compliance to campus alerts',
#  'direct output connection for a high-rank language model',
#  'sequence alignment detection of tcp-targeted synchronous low-rate dos attacks',
#  'species diversity defends against the invasion of nile tilapia (oreochromis niloticus)',
#  'insights into the role of cu in promoting photocatalytichydrogenproductionoverultrathinhnb3o8 nanosheets',
#  'release from herbivory does not confer invasion success for eugenia uniflora in florida',
#  'methyl styrene (vinyl toluene) (all isomers) [mak value documentation, 2017]',
#  'can encryption for automotive application',
#  'development of a real-time three-dimensional spinal motion measurement system for clinical practice',
#  'thiodiethylene bis[3‐(3,5‐di‐tert‐butyl‐4‐hydroxyphenyl)propionate] [mak value documentation, 2018]',
#  'driving investment, trade and the creation of wealth across asia, africa and the middle east',
#  'natriumpyrithion [mak value documentation in german language, 2019]',
#  'tree species diversity reduces the invasibility of maritime pine stands by the bast scale, matsucoccus feytaudi (homoptera: margarodidae)',
#  'representing and reasoning about xml with ontologies',
#  'competitive replacement of invasive congeners may relax impact on native species',
#  'the automatic content extraction (ace) program–tasks, data, and evaluation',
#  'broom and honeybees in australia: an alien liaison',
#  'n‐methyl‐2‐pyrrolidon (dampf) [mak value documentation in german language, 2019]',
#  'interactions between two introduced species: zostera japonica (dwarf eelgrass) facilitates itself and reduces condition of ruditapes philippinarum (manila clam) on intertidal flats',
#  'biofuels e economic aspects',
#  'quantifying "apparent" impact and distinguishing impact from invasiveness in multispecies plant invasions',
#  'benzyl alcohol – method for the determination of benzyl alcohol in workplace air using gas chromatography after thermal desorption [air monitoring methods, 2018]',
#  'distributed denial of service (ddos) attack mitigation in software defined network (sdn)-based cloud computing environment',
#  'semantics and data graph semantics based on the national map',
#  'a class of band-limited chip waveforms for ds-cdma systems',
#  'experimental test of the invasional meltdown hypothesis: na exotic herbivore facilitates na exotic plant, but the plant does not reciprocally facilitate the herbivore',
#  'using prairie restoration to curtail invasion of canada thistle: the importance of limiting similarity and seed mix richness',
#  'host introduction and parasites: a case study on the parasite community of the peacock grouper cephalopholis argus (serranidae) in the hawaiian islands',
#  'are introduced rats (rattus rattus) both seed predators and dispersers in hawaii?',
#  'improving the detection of mtbi via complexity analysis in resting � state magnetoencephalography',
#  'the k-anonymity and l-diversity approaches for privacy preservation in social networks against neighborhood attacks',
#  'luke: deep contextualized entity representations with entity-aware self-attention',
#  'mortality factors affecting agrilus auroguttatus schaeffer (coleoptera: buprestidae) eggs in the native and invaded ranges',
#  'aquatic plant community invasibility and scale-dependent patterns in native and invasive species richness',
#  'ict-enabled community empowermentin crisis response: social media in thailand flooding 2011.',
#  'privacy-preserving all convolutional net based on homomorphic encryption',
#  'comparisons of arthropod assemblages on an invasive and native trees: abundance, diversity and damage',
#  'release from native root herbivores and biotic resistance by soil pathogens in a new habitat both affect the alien ammophila arenaria in south africa',
#  'determinants of solid waste management system in uyo metropolis, akwa ibom state, nigeria',
#  'towards a semantic data quality management-using ontologies to assess master data quality in retailing',
#  'impact of open access on citation of scholarly publications in the field of civil engineering',
#  'baseline technical and assessment of a commercial scale fischeretropsch liquids fa- cility. netl',
#  'increased chemical resistance explains low herbivore colonization of introduced seaweed',
#  'bio-id track overview',
#  'recall-oriented learning of named entities in arabic wikipedia',
#  'thumbs up?: sentiment classification using machine learning techniques',
#  'multi-objective fuzzy mathematical modelling of closed-loop supply chain considering economical and environmental factors',
#  'natural and anthropogenic factors affecting the shallow groundwater quality in a typical irrigation area with reclaimed water, north china plain',
#  'hybrid deep learning model for automatic fake news detection',
#  'lc-quad: a corpus for complex question answering over knowledge graphs',
#  'emergency response information systeminteroperability: development of chemical incidentresponse data model',
#  'simple heuristics for the assembly line worker assignment and balancing problem',
#  'comparison of topical 0.7% dexamethasone–cyclodextrin with 0.1% dexamethasone sodium phosphate for postcataract inflammation',
#  'an ontology based modeling framework for design of educational technologies',
#  'comparative efficacy of behavioral and cognitive therapies of depression',
#  'recruitment limitation, seedling performance and persistence of exotic tree monocultures',
#  'a comparison of native and introduced populations of the south african ragwort senecio inaequidens dc. in the field',
#  'avian seed dispersal of an invasive shrub',
#  'linking the pattern to the mechanism: how na introduced mammal facilitates plant invasions',
#  'proofs of data possession and retrievability based on mrd codes$_\\ast$',
#  'sars-cov-2 receptor ace2 is an interferon-stimulated gene in human airway epithelial cells and is detected in specific cell subsets across tissues',
#  'foodkg enabled q&a application',
#  'do alien plants on mediterranean islands tend to invade different niches from native species?',
#  'report 3: transmissibility of 2019- ncov',
#  'app store mining is not enough for app improvement',
#  'a genetic algorithm for scheduling flexible manufacturing cells',
#  'detection of cyberbullying incidents on the instagram social network',
#  'mac users do it differently: the role of operating system and individual differences in file management',
#  'a new methodology to support group decision-makingfor iot-based emergency response systems',
#  "levit: a vision transformer in convnet's clothing for faster inference",
#  'journal publishing in developing, transition and emerging countries: proceedings of the 5th belgrade international open access conference',
#  'alcohols, ketones and ethers – determination of alcohols, ketones and ethers in urine by headspace gc-ms. biomonitoring method – translation of the german version from 2020',
#  'geolocation estimation of photos using a hierarchical model and scene classification',
#  'machine intelligence-based algorithms for spam filtering on document labeling',
#  'significant flux of atmospheric nitrous oxide from the northwest indian ocean',
#  'interactions between abiotic constraint, propagule pressure, and biotic resistance regulate plant invasion',
#  'lc-quad 2.0: a large dataset for complex question answering over wikidata and dbpedia',
#  'non-native plant invader renders suitable habitat unsuitable',
#  'residual attention u-net for automated multi-class segmentation of covid-19 chest ct images',
#  'comparing three online civic engagement platforms using the “spectrum of public participation” framework',
#  'an open-source integrated framework for the automation of citation collection and screening in systematic reviews',
#  'range expansion and population dynamics of co-occuring invasive herbivores',
#  'increased repertoire of network microstates in _ frequency for mild traumatic brain injury subjects: a meg beamformed connectivity analysis.',
#  'unsupervised author disambiguation using dempster–shafer theory',
#  'pharmacokinetic analysis of single dose extended release levetiracetam per os in healthy cats',
#  'two new phytoecdysteroids from sphenocentrum jollyanum pierre root',
#  'the targeting of large-sized benthic macrofauna by na invasive portunid predator: evidence form a caging study',
#  'chemical composition of the essential oil of artemisia herba-alba asso ssp. valentine (lam.) marcl',
#  'detection of fake news in a new corpus for the spanish language',
#  'an automatic procedure for small vessel detection from very-high resolution optical imagery',
#  'results of an analysis of existing fair assessment tools',
#  'influence of accessibility (open and toll-based) of scholarly publications on retractions',
#  'are interactions among ponto-caspian invaders driving amphipod species replacement in the st. lawrence river?',
#  'addendum to nitrobenzene [bat value documentation, 2017]',
#  'alien pollinator promotes invasive mutualism in na insular pollination system',
#  'small vessel detection in high quality optical satellite imagery',
#  'ontonotes release 4.0',
#  'wide bandgap semiconductor thin films for piezoelectric and piezoresistive mems sensors applied at high temperatures: an overview',
#  'strategies for handling missing clinical data for automated surgical site infection detection from the electronic health record',
#  'mutualism between fire ants and mealybugs reduce lady beetle predation',
#  'biodiversity as a barrier to ecological invasion',
#  'effect of microbial species richness on community stability and community function in a model plant-based wastewater processing system',
#  'determination of metal-containing components of airborne particles. air monitoring method – translation of the german version from 2019',
#  'teamwork and collaboration',
#  'do open access journal articles experience a citation advantage? results and methodological reflections of an application of multiple measures to an analysis by wos subject areas',
#  'n‐methyl‐2‐pyrrolidone (vapour)1) [mak value documentation, 2019]',
#  'rnn simulations of grammaticality judgments on long-distance dependencies',
#  'quieter cars and the safety of blind pedestrians: phase i, report dot hs 811 304',
#  'from first reports to successful control: a plea for improved management of alien aquatic plant species in germany',
#  'seal: sdn based secure and agile framework for protecting smart city applications from ddos attacks',
#  'contrasting patterns of spread in interacting invasive species: membranipora membranacea and codium fragile off nova scotia',
#  'municipal financial reporting on the world wide web',
#  'phytochemical screening and effect of ethanolic root extract of uvaria chamae on haematological parameters on albino rats in akwa ibom state, nigeria',
#  'beyond biodiversity: individualistic controls of invasion in a self-assembled community',
#  'information systems and health care xiii: examining the critical requirements,design approaches and evaluation methods for a public health emergency response system',
#  'butylated hydroxytoluene (bht) – determination of 3,5 di-tert-butyl-4-hydroxybenzoic acid (bht acid) in urine by lc-ms/ms. biomonitoring method – translation of the german version from 2020',
#  'rare species loss alters ecosystem function - invasion resistance',
#  'emergency response information systems: emerging trendsin emergency management',
#  'cloud computing',
#  'an improved decision support system for detection of lesions in mammograms using differential evolution optimized wavelet neural network',
#  'sustainable forest management in sardegna: from wood to timber, the role of taper functions',
#  'formation of silicon by electrodeoxidation, and implications for titanium metal production']
