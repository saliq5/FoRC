# %%
import numpy as np
import pandas as pd
import transformers
import torch
import re
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from torch import nn
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('/kaggle/input/forcdtaaa/train.csv')
data.drop(['doi','url','publication month', 'publication year','publisher', 'data_index'], axis =1 , inplace = True)
data = data.dropna()
data["text"] = data["title"] + data["abstract"]
data
# Out:
#                                                 abstract  \
# 0      the production of b jets in association with a...
# 1      instabilities in the price dynamics of a large...
# 2      large information sizes in samples and feature...
# 3      we consider polygonal billiards with collision...
# 4      Bauxite deposits of Jharkhand in India are res...
# ...                                                  ...
# 41534  programs offered by academic institutions in h...
# 41535  this research addresses the competencies organ...
# 41536  this paper studies an optimal stopping problem...
# 41537  we examine the possible extension of the param...
# 41539  what happens to the entropy increase principle...
#
#                                                   author  \
# 0                                      CMS Collaboration
# 1      Giacomo Bormetti, Lucio Maria Calcagnile, Mich...
# 2                                 David Banh, Alan Huang
# 3      Gianluigi Del Magno, Jo\~ao Lopes Dias, Pedro ...
# 4      ['E.N. Dhanamjaya Rao', 'A.T. Jeyaseelan', 'K....
# ...                                                  ...
# 41534                  ['Alex Ferworn', 'Muthana Zouri']
# 41535        ['Sabik Khan', 'Marcus Ho', 'Kamrul Ahsan']
# 41536                          Diana Dorobantu (LSProba)
# 41537  John Ellis, Joel Giedt, Oleg Lebedev, Keith Ol...
# 41539                                            K.Ghosh
#
#                                                    title  \
# 0      Measurement of the Z/gamma* + b-jet cross sect...
# 1      Modelling systemic price cojumps with Hawkes f...
# 2      Encoding large information structures in linea...
# 3      Hyperbolic polygonal billiards close to 1-dime...
# 4      analysis of aster data for mapping bauxite ric...
# ...                                                  ...
# 41534  an ontology-based approach for curriculum mapp...
# 41535  recruiting project managers: a comparative ana...
# 41536  Optimal stopping for L\'evy processes and affi...
# 41537                               Against Tachyophobia
# 41539  Studies on Some Aspects of the Fundamental The...
#
#                                     label  \
# 0                                 Physics
# 1                    Quantitative Finance
# 2                        Machine Learning
# 3              Dynamics/Dynamical Systems
# 4                               Sociology
# ...                                   ...
# 41534                Computer Engineering
# 41535                           Sociology
# 41536          Statistics and Probability
# 41537                             Physics
# 41539  Cosmology, Relativity, and Gravity
#
#                                                     text
# 0      Measurement of the Z/gamma* + b-jet cross sect...
# 1      Modelling systemic price cojumps with Hawkes f...
# 2      Encoding large information structures in linea...
# 3      Hyperbolic polygonal billiards close to 1-dime...
# 4      analysis of aster data for mapping bauxite ric...
# ...                                                  ...
# 41534  an ontology-based approach for curriculum mapp...
# 41535  recruiting project managers: a comparative ana...
# 41536  Optimal stopping for L\'evy processes and affi...
# 41537  Against Tachyophobiawe examine the possible ex...
# 41539  Studies on Some Aspects of the Fundamental The...
#
# [40332 rows x 5 columns]

# %%
def NLP_cleaning(text):
    text_corpus = []
    i=0
    for sent in tqdm(text, desc='Cleaning'):
        # print(i, end =" ")
        i+=1
        sent = re.sub('<[^>]*>', '', sent)
        sent = re.sub('[^a-zA-z0-9]', ' ', sent)
        sent = sent.lower()
        text_corpus.append(sent)

    return text_corpus

# %%
text = data.text.values.tolist()
text_corpus = NLP_cleaning(text)
data['text'] = text_corpus
data['title'] = NLP_cleaning(data.title.values.tolist())
data['author'] = NLP_cleaning(data.author.values.tolist())
# Out:
# Cleaning: 100%|██████████| 40332/40332 [00:03<00:00, 11839.25it/s]
# Cleaning: 100%|██████████| 40332/40332 [00:00<00:00, 105971.39it/s]
# Cleaning: 100%|██████████| 40332/40332 [00:00<00:00, 81643.26it/s]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['label_number'] = label_encoder.fit_transform(data['label'])
data
# Out:
#                                                 abstract  \
# 0      the production of b jets in association with a...
# 1      instabilities in the price dynamics of a large...
# 2      large information sizes in samples and feature...
# 3      we consider polygonal billiards with collision...
# 4      Bauxite deposits of Jharkhand in India are res...
# ...                                                  ...
# 41534  programs offered by academic institutions in h...
# 41535  this research addresses the competencies organ...
# 41536  this paper studies an optimal stopping problem...
# 41537  we examine the possible extension of the param...
# 41539  what happens to the entropy increase principle...
#
#                                                   author  \
# 0                                      cms collaboration
# 1      giacomo bormetti  lucio maria calcagnile  mich...
# 2                                 david banh  alan huang
# 3      gianluigi del magno  jo\ ao lopes dias  pedro ...
# 4      [ e n  dhanamjaya rao    a t  jeyaseelan    k ...
# ...                                                  ...
# 41534                  [ alex ferworn    muthana zouri ]
# 41535        [ sabik khan    marcus ho    kamrul ahsan ]
# 41536                          diana dorobantu  lsproba
# 41537  john ellis  joel giedt  oleg lebedev  keith ol...
# 41539                                            k ghosh
#
#                                                    title  \
# 0      measurement of the z gamma    b jet cross sect...
# 1      modelling systemic price cojumps with hawkes f...
# 2      encoding large information structures in linea...
# 3      hyperbolic polygonal billiards close to 1 dime...
# 4      analysis of aster data for mapping bauxite ric...
# ...                                                  ...
# 41534  an ontology based approach for curriculum mapp...
# 41535  recruiting project managers  a comparative ana...
# 41536  optimal stopping for l\ evy processes and affi...
# 41537                               against tachyophobia
# 41539  studies on some aspects of the fundamental the...
#
#                                     label  \
# 0                                 Physics
# 1                    Quantitative Finance
# 2                        Machine Learning
# 3              Dynamics/Dynamical Systems
# 4                               Sociology
# ...                                   ...
# 41534                Computer Engineering
# 41535                           Sociology
# 41536          Statistics and Probability
# 41537                             Physics
# 41539  Cosmology, Relativity, and Gravity
#
#                                                     text  label_number
# 0      measurement of the z gamma    b jet cross sect...            95
# 1      modelling systemic price cojumps with hawkes f...           105
# 2      encoding large information structures in linea...            67
# 3      hyperbolic polygonal billiards close to 1 dime...            41
# 4      analysis of aster data for mapping bauxite ric...           114
# ...                                                  ...           ...
# 41534  an ontology based approach for curriculum mapp...            25
# 41535  recruiting project managers  a comparative ana...           114
# 41536  optimal stopping for l\ evy processes and affi...           118
# 41537  against tachyophobiawe examine the possible ex...            95
# 41539  studies on some aspects of the fundamental the...            34
#
# [40332 rows x 6 columns]

# %%
val_df = pd.read_csv('/kaggle/input/forcdtaaa/val.csv')
val_df.drop(['doi','url','publication month', 'publication year','publisher', 'data_index'], axis =1 , inplace = True)
val_df = val_df.dropna()
val_df['label_number'] = label_encoder.transform(val_df['label'])
val_df["text"] = val_df["title"] + val_df["abstract"]
val_df['title'] = NLP_cleaning(val_df.title.values.tolist())
val_df['author'] = NLP_cleaning(val_df.author.values.tolist())
val_df['abstract'] = NLP_cleaning(val_df.abstract.values.tolist())
val_df['text'] = NLP_cleaning(val_df.text.values.tolist())
# Out:
# Cleaning: 100%|██████████| 8648/8648 [00:00<00:00, 97780.97it/s]
# Cleaning: 100%|██████████| 8648/8648 [00:00<00:00, 82819.99it/s]
# Cleaning: 100%|██████████| 8648/8648 [00:00<00:00, 12323.08it/s]
# Cleaning: 100%|██████████| 8648/8648 [00:00<00:00, 11664.16it/s]

# %%
# !pip install -q sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# # Proper Experiment

# %%
X_train = data['text']
X_train = X_train.to_list()
Y_train = data['label_number']
Y_train = Y_train.to_list()

# %%
X_test = val_df['text'].to_list()
Y_test = val_df['label_number'].to_list()

# %%
train_embeddings = model.encode(X_train)
test_embeddings = model.encode(X_test)
# Out:
# Batches:   0%|          | 0/1261 [00:00<?, ?it/s]

# %%
len(train_embeddings)
# Out:
# 40332

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import SVC
svm = SVC()

svm.fit(train_embeddings,Y_train)
y_pred = svm.predict(test_embeddings)

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ",accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.7119565217391305
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.73      0.72        99
#            1       0.80      0.80      0.80       126
#            2       0.64      0.70      0.67       130
#            3       0.86      1.00      0.92        12
#            4       0.62      0.52      0.56       118
#            5       0.43      0.20      0.27        30
#            6       0.61      0.50      0.55       104
#            7       0.71      0.56      0.63         9
#            8       0.52      0.71      0.60       557
#            9       0.60      0.27      0.37        11
#           10       0.68      0.68      0.68       225
#           11       0.00      0.00      0.00         3
#           12       0.70      0.92      0.80       189
#           13       0.70      0.33      0.45        42
#           14       0.00      0.00      0.00         3
#           15       0.83      0.56      0.67         9
#           16       0.00      0.00      0.00         2
#           17       0.78      0.78      0.78        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.81      0.38      0.52        34
#           21       0.00      0.00      0.00         9
#           22       0.67      0.55      0.60        11
#           23       0.71      0.93      0.81       167
#           24       0.00      0.00      0.00         9
#           25       0.73      0.55      0.63        29
#           26       0.70      0.70      0.70        20
#           27       0.40      0.23      0.29       100
#           28       0.82      0.95      0.88       268
#           29       0.95      0.67      0.78        27
#           30       0.32      0.29      0.30        24
#           31       0.54      0.43      0.48       179
#           32       0.50      0.21      0.30        19
#           33       0.78      0.30      0.43       135
#           34       0.67      0.77      0.72       180
#           35       0.81      0.90      0.85        69
#           36       0.00      0.00      0.00         4
#           37       0.53      0.58      0.55        53
#           38       0.57      0.75      0.65        87
#           39       0.25      0.25      0.25         4
#           40       0.79      0.81      0.80       180
#           41       0.78      0.77      0.78       272
#           42       1.00      0.55      0.71        20
#           43       0.86      0.94      0.90        33
#           44       0.00      0.00      0.00         4
#           45       0.00      0.00      0.00         5
#           46       0.48      0.75      0.59        20
#           47       0.67      0.14      0.24        14
#           49       0.54      0.41      0.47        34
#           50       0.79      0.73      0.76        15
#           51       0.75      0.41      0.53       175
#           52       0.72      0.80      0.76        61
#           53       0.00      0.00      0.00         4
#           54       0.78      0.88      0.83       215
#           55       1.00      0.57      0.73         7
#           56       1.00      0.50      0.67         6
#           57       1.00      0.38      0.56        13
#           58       0.00      0.00      0.00        12
#           59       0.50      0.46      0.48        26
#           60       1.00      0.11      0.20         9
#           61       0.73      0.67      0.70        60
#           62       0.67      0.33      0.44        18
#           63       0.71      0.56      0.63        84
#           64       0.56      0.42      0.48        24
#           65       1.00      1.00      1.00         7
#           66       0.76      0.74      0.75        35
#           67       0.52      0.69      0.60        77
#           68       0.67      0.71      0.69       235
#           69       0.00      0.00      0.00         1
#           70       0.62      0.59      0.61       151
#           71       0.60      0.30      0.40        10
#           72       0.00      0.00      0.00         5
#           73       0.78      0.89      0.83        93
#           74       0.44      0.29      0.35        14
#           75       0.92      0.92      0.92        24
#           76       1.00      0.45      0.62        11
#           77       0.92      0.90      0.91        49
#           78       0.44      0.44      0.44         9
#           79       0.00      0.00      0.00         3
#           80       0.91      0.56      0.69        18
#           81       0.00      0.00      0.00         1
#           82       0.78      0.93      0.85        15
#           83       0.50      0.17      0.25         6
#           84       0.72      0.64      0.68       209
#           85       0.75      0.83      0.79       104
#           86       0.62      0.64      0.63        53
#           87       0.00      0.00      0.00         1
#           88       0.95      1.00      0.97        19
#           89       1.00      1.00      1.00         7
#           90       0.72      0.88      0.79        33
#           91       0.72      0.75      0.74       104
#           92       0.00      0.00      0.00         1
#           93       0.59      0.46      0.51       138
#           94       0.00      0.00      0.00         4
#           95       0.77      0.85      0.80       933
#           96       0.67      0.67      0.67         9
#           97       0.36      0.35      0.36        23
#           98       0.82      0.65      0.73        49
#           99       0.00      0.00      0.00         7
#          100       0.79      0.52      0.63        21
#          101       0.73      0.44      0.55        36
#          102       0.00      0.00      0.00         2
#          103       0.85      0.73      0.79        30
#          104       1.00      0.17      0.29        12
#          105       0.29      0.57      0.38         7
#          106       0.00      0.00      0.00         7
#          107       0.86      0.88      0.87       812
#          108       0.83      0.92      0.87        63
#          109       1.00      0.86      0.92         7
#          110       0.75      1.00      0.86         3
#          111       0.76      0.76      0.76        55
#          112       0.70      0.51      0.59        45
#          113       1.00      0.11      0.19        19
#          114       0.80      0.57      0.67         7
#          115       0.77      0.87      0.82        95
#          116       0.00      0.00      0.00         6
#          117       0.64      0.75      0.69        56
#          118       0.75      0.81      0.78       130
#          119       0.71      0.70      0.70       233
#          120       0.55      0.68      0.61        80
#          121       0.00      0.00      0.00         2
#          122       1.00      1.00      1.00        11
#
#     accuracy                           0.71      8648
#    macro avg       0.58      0.50      0.52      8648
# weighted avg       0.71      0.71      0.70      8648

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(train_embeddings, Y_train)

y_pred = rf.predict(test_embeddings)

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ",accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.5712303422756707
#
# -----------------------------------------------
#
#
#
#
#
#               precision    recall  f1-score   support
#
#
#
#            0       0.55      0.63      0.58        99
#
#            1       0.77      0.70      0.73       126
#
#            2       0.58      0.48      0.53       130
#
#            3       0.88      0.58      0.70        12
#
#            4       0.53      0.15      0.24       118
#
#            5       1.00      0.03      0.06        30
#
#            6       0.46      0.28      0.35       104
#
#            7       0.00      0.00      0.00         9
#
#            8       0.42      0.83      0.56       557
#
#            9       0.00      0.00      0.00        11
#
#           10       0.72      0.45      0.55       225
#
#           11       0.00      0.00      0.00         3
#
#           12       0.46      0.86      0.60       189
#
#           13       0.00      0.00      0.00        42
#
#           14       0.00      0.00      0.00         3
#
#           15       0.00      0.00      0.00         9
#
#           16       0.00      0.00      0.00         2
#
#           17       0.83      0.51      0.63        37
#
#           18       0.00      0.00      0.00         1
#
#           19       0.00      0.00      0.00         5
#
#           20       0.83      0.15      0.25        34
#
#           21       0.00      0.00      0.00         9
#
#           22       0.00      0.00      0.00        11
#
#           23       0.59      0.96      0.73       167
#
#           24       0.00      0.00      0.00         9
#
#           25       0.71      0.41      0.52        29
#
#           26       0.75      0.30      0.43        20
#
#           27       0.40      0.12      0.18       100
#
#           28       0.59      0.96      0.73       268
#
#           29       1.00      0.44      0.62        27
#
#           30       0.33      0.04      0.07        24
#
#           31       0.42      0.28      0.34       179
#
#           32       0.00      0.00      0.00        19
#
#           33       0.67      0.01      0.03       135
#
#           34       0.72      0.56      0.63       180
#
#           35       0.64      0.78      0.71        69
#
#           36       0.00      0.00      0.00         4
#
#           37       0.44      0.30      0.36        53
#
#           38       0.49      0.68      0.57        87
#
#           39       0.00      0.00      0.00         4
#
#           40       0.57      0.80      0.67       180
#
#           41       0.59      0.75      0.66       272
#
#           42       0.89      0.40      0.55        20
#
#           43       0.76      0.94      0.84        33
#
#           44       0.00      0.00      0.00         4
#
#           45       0.00      0.00      0.00         5
#
#           46       0.44      0.20      0.28        20
#
#           47       1.00      0.07      0.13        14
#
#           49       0.62      0.24      0.34        34
#
#           50       0.62      0.33      0.43        15
#
#           51       1.00      0.03      0.06       175
#
#           52       0.76      0.46      0.57        61
#
#           53       0.00      0.00      0.00         4
#
#           54       0.62      0.77      0.69       215
#
#           55       0.00      0.00      0.00         7
#
#           56       1.00      0.17      0.29         6
#
#           57       0.00      0.00      0.00        13
#
#           58       0.00      0.00      0.00        12
#
#           59       0.00      0.00      0.00        26
#
#           60       0.00      0.00      0.00         9
#
#           61       0.70      0.55      0.62        60
#
#           62       1.00      0.17      0.29        18
#
#           63       0.73      0.10      0.17        84
#
#           64       0.20      0.04      0.07        24
#
#           65       1.00      0.14      0.25         7
#
#           66       0.90      0.26      0.40        35
#
#           67       0.38      0.29      0.33        77
#
#           68       0.52      0.59      0.55       235
#
#           69       0.00      0.00      0.00         1
#
#           70       0.53      0.34      0.42       151
#
#           71       0.00      0.00      0.00        10
#
#           72       0.00      0.00      0.00         5
#
#           73       0.92      0.51      0.65        93
#
#           74       0.00      0.00      0.00        14
#
#           75       0.94      0.67      0.78        24
#
#           76       0.67      0.18      0.29        11
#
#           77       0.91      0.84      0.87        49
#
#           78       0.00      0.00      0.00         9
#
#           79       0.00      0.00      0.00         3
#
#           80       0.00      0.00      0.00        18
#
#           81       0.00      0.00      0.00         1
#
#           82       0.89      0.53      0.67        15
#
#           83       1.00      0.17      0.29         6
#
#           84       0.73      0.23      0.36       209
#
#           85       0.65      0.74      0.69       104
#
#           86       0.70      0.40      0.51        53
#
#           87       0.00      0.00      0.00         1
#
#           88       1.00      1.00      1.00        19
#
#           89       1.00      0.71      0.83         7
#
#           90       0.68      0.85      0.76        33
#
#           91       0.81      0.24      0.37       104
#
#           92       0.00      0.00      0.00         1
#
#           93       0.64      0.07      0.12       138
#
#           94       0.00      0.00      0.00         4
#
#           95       0.51      0.86      0.64       933
#
#           96       1.00      0.11      0.20         9
#
#           97       1.00      0.04      0.08        23
#
#           98       0.50      0.06      0.11        49
#
#           99       0.00      0.00      0.00         7
#
#          100       0.00      0.00      0.00        21
#
#          101       1.00      0.06      0.11        36
#
#          102       0.00      0.00      0.00         2
#
#          103       0.87      0.67      0.75        30
#
#          104       0.00      0.00      0.00        12
#
#          105       0.00      0.00      0.00         7
#
#          106       0.00      0.00      0.00         7
#
#          107       0.64      0.91      0.75       812
#
#          108       0.86      0.48      0.61        63
#
#          109       1.00      0.57      0.73         7
#
#          110       1.00      0.67      0.80         3
#
#          111       0.88      0.42      0.57        55
#
#          112       0.80      0.09      0.16        45
#
#          113       1.00      0.05      0.10        19
#
#          114       0.00      0.00      0.00         7
#
#          115       0.68      0.73      0.70        95
#
#          116       0.00      0.00      0.00         6
#
#          117       0.71      0.27      0.39        56
#
#          118       0.66      0.69      0.67       130
#
#          119       0.64      0.50      0.56       233
#
#          120       0.51      0.40      0.45        80
#
#          121       0.00      0.00      0.00         2
#
#          122       1.00      0.36      0.53        11
#
#
#
#     accuracy                           0.57      8648
#
#    macro avg       0.47      0.28      0.31      8648
#
# weighted avg       0.59      0.57      0.52      8648

# %% [markdown]
# ## Neural Network

# %% [markdown]
# ## Model 1

# %%
import tensorflow as tf

input_dim = 384
num_classes = 123

model1 = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(input_dim,)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])
model1.compile(optimizer='adam',
              loss= 'sparse_categorical_crossentropy',
             metrics=['accuracy'])

model1.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 256)               98560
#
#  dropout_16 (Dropout)        (None, 256)               0
#
#  dense_21 (Dense)            (None, 512)               131584
#
#  dropout_17 (Dropout)        (None, 512)               0
#
#  dense_22 (Dense)            (None, 256)               131328
#
#  dropout_18 (Dropout)        (None, 256)               0
#
#  dense_23 (Dense)            (None, 128)               32896
#
#  dropout_19 (Dropout)        (None, 128)               0
#
#  dense_24 (Dense)            (None, 123)               15867
#
# =================================================================
# Total params: 410235 (1.56 MB)
# Trainable params: 410235 (1.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
Y_train = np.array(Y_train)

train_accuracy = []
train_loss = []

epochs = 10
for epoch in range(epochs):
    print(f"\nEpoch {epoch + 1}/{epochs}")
    history = model1.fit(train_embeddings, Y_train, batch_size=16)
    train_loss.append(history.history['loss'][0])
    train_acc = history.history['accuracy'][0]
    train_accuracy.append(train_acc)
    print(f"Training Loss: {train_loss[-1]}, Training Accuracy: {train_acc}")
# Out:
# Epoch 1/10
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1708419706.347542     210 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2521/2521 [==============================] - 12s 3ms/step - loss: 1.9812 - accuracy: 0.4676
# Training Loss: 1.9812408685684204, Training Accuracy: 0.46756917238235474
#
# Epoch 2/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 1.4135 - accuracy: 0.5915
# Training Loss: 1.413461685180664, Training Accuracy: 0.5915154218673706
#
# Epoch 3/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 1.2595 - accuracy: 0.6250
# Training Loss: 1.2594672441482544, Training Accuracy: 0.6250371932983398
#
# Epoch 4/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 1.1527 - accuracy: 0.6481
# Training Loss: 1.152707576751709, Training Accuracy: 0.6481453776359558
#
# Epoch 5/10
# 2521/2521 [==============================] - 9s 4ms/step - loss: 1.0769 - accuracy: 0.6686
# Training Loss: 1.0768930912017822, Training Accuracy: 0.6685758233070374
#
# Epoch 6/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 1.0139 - accuracy: 0.6847
# Training Loss: 1.0138516426086426, Training Accuracy: 0.6847168207168579
#
# Epoch 7/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 0.9643 - accuracy: 0.6951
# Training Loss: 0.9642525911331177, Training Accuracy: 0.6950560212135315
#
# Epoch 8/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 0.9131 - accuracy: 0.7101
# Training Loss: 0.913070559501648, Training Accuracy: 0.7100813388824463
#
# Epoch 9/10
# 2521/2521 [==============================] - 9s 4ms/step - loss: 0.8776 - accuracy: 0.7175
# Training Loss: 0.8776075839996338, Training Accuracy: 0.7174699902534485
#
# Epoch 10/10
# 2521/2521 [==============================] - 9s 3ms/step - loss: 0.8466 - accuracy: 0.7267
# Training Loss: 0.8465852737426758, Training Accuracy: 0.7267430424690247

# %%
y_pred_prob = model1.predict(test_embeddings)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 271/271 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.6653561517113784
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.65      0.66        99
#            1       0.73      0.82      0.77       126
#            2       0.66      0.62      0.63       130
#            3       0.79      0.92      0.85        12
#            4       0.60      0.44      0.51       118
#            5       0.35      0.23      0.28        30
#            6       0.50      0.31      0.38       104
#            7       0.22      0.22      0.22         9
#            8       0.55      0.38      0.45       557
#            9       0.67      0.36      0.47        11
#           10       0.59      0.70      0.64       225
#           11       0.00      0.00      0.00         3
#           12       0.71      0.87      0.78       189
#           13       0.64      0.17      0.26        42
#           14       0.00      0.00      0.00         3
#           15       0.20      0.22      0.21         9
#           16       0.00      0.00      0.00         2
#           17       0.68      0.73      0.70        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.66      0.56      0.60        34
#           21       0.17      0.11      0.13         9
#           22       0.50      0.27      0.35        11
#           23       0.70      0.88      0.78       167
#           24       0.17      0.22      0.19         9
#           25       0.43      0.52      0.47        29
#           26       0.79      0.55      0.65        20
#           27       0.31      0.22      0.26       100
#           28       0.80      0.90      0.85       268
#           29       0.85      0.63      0.72        27
#           30       0.16      0.21      0.18        24
#           31       0.47      0.40      0.43       179
#           32       0.12      0.05      0.07        19
#           33       0.61      0.47      0.53       135
#           34       0.67      0.78      0.72       180
#           35       0.75      0.84      0.79        69
#           36       0.00      0.00      0.00         4
#           37       0.49      0.47      0.48        53
#           38       0.57      0.57      0.57        87
#           39       0.25      0.25      0.25         4
#           40       0.79      0.77      0.78       180
#           41       0.75      0.75      0.75       272
#           42       0.71      0.50      0.59        20
#           43       0.88      0.91      0.90        33
#           44       0.00      0.00      0.00         4
#           45       0.00      0.00      0.00         5
#           46       0.38      0.85      0.52        20
#           47       1.00      0.07      0.13        14
#           49       0.39      0.32      0.35        34
#           50       0.54      0.47      0.50        15
#           51       0.47      0.68      0.56       175
#           52       0.59      0.77      0.67        61
#           53       0.00      0.00      0.00         4
#           54       0.76      0.75      0.75       215
#           55       1.00      0.57      0.73         7
#           56       0.43      0.50      0.46         6
#           57       0.62      0.62      0.62        13
#           58       0.25      0.08      0.12        12
#           59       0.30      0.31      0.30        26
#           60       0.20      0.11      0.14         9
#           61       0.69      0.62      0.65        60
#           62       0.25      0.11      0.15        18
#           63       0.55      0.70      0.61        84
#           64       0.50      0.25      0.33        24
#           65       1.00      0.86      0.92         7
#           66       0.57      0.77      0.66        35
#           67       0.48      0.52      0.50        77
#           68       0.59      0.70      0.64       235
#           69       0.00      0.00      0.00         1
#           70       0.60      0.58      0.59       151
#           71       0.33      0.40      0.36        10
#           72       0.00      0.00      0.00         5
#           73       0.84      0.78      0.81        93
#           74       0.38      0.21      0.27        14
#           75       0.91      0.83      0.87        24
#           76       0.50      0.45      0.48        11
#           77       0.80      0.96      0.87        49
#           78       0.25      0.44      0.32         9
#           79       0.00      0.00      0.00         3
#           80       0.53      0.50      0.51        18
#           81       0.00      0.00      0.00         1
#           82       0.63      0.80      0.71        15
#           83       0.50      0.33      0.40         6
#           84       0.64      0.70      0.67       209
#           85       0.71      0.80      0.75       104
#           86       0.54      0.68      0.60        53
#           87       0.00      0.00      0.00         1
#           88       0.90      1.00      0.95        19
#           89       0.58      1.00      0.74         7
#           90       0.81      0.76      0.78        33
#           91       0.69      0.74      0.71       104
#           92       0.00      0.00      0.00         1
#           93       0.51      0.67      0.58       138
#           94       0.00      0.00      0.00         4
#           95       0.82      0.77      0.79       933
#           96       0.35      0.78      0.48         9
#           97       0.12      0.09      0.10        23
#           98       0.79      0.55      0.65        49
#           99       0.00      0.00      0.00         7
#          100       0.60      0.57      0.59        21
#          101       0.73      0.31      0.43        36
#          102       0.00      0.00      0.00         2
#          103       0.54      0.73      0.62        30
#          104       1.00      0.33      0.50        12
#          105       0.00      0.00      0.00         7
#          106       0.00      0.00      0.00         7
#          107       0.86      0.84      0.85       812
#          108       0.84      0.90      0.87        63
#          109       0.75      0.86      0.80         7
#          110       0.60      1.00      0.75         3
#          111       0.64      0.80      0.71        55
#          112       0.55      0.38      0.45        45
#          113       0.20      0.11      0.14        19
#          114       0.00      0.00      0.00         7
#          115       0.72      0.82      0.77        95
#          116       0.00      0.00      0.00         6
#          117       0.57      0.70      0.63        56
#          118       0.66      0.76      0.71       130
#          119       0.61      0.77      0.68       233
#          120       0.49      0.62      0.55        80
#          121       0.00      0.00      0.00         2
#          122       1.00      0.91      0.95        11
#
#     accuracy                           0.67      8648
#    macro avg       0.47      0.46      0.45      8648
# weighted avg       0.66      0.67      0.66      8648

# %% [markdown]
# ## Model 2

# %%
input_dim = 384
num_classes = 123

model2 = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(input_dim,)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# Compile the model
model2.compile(optimizer='adam',
              loss= 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model2.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 256)               98560
#
#  dropout_20 (Dropout)        (None, 256)               0
#
#  dense_26 (Dense)            (None, 512)               131584
#
#  dropout_21 (Dropout)        (None, 512)               0
#
#  dense_27 (Dense)            (None, 1024)              525312
#
#  dropout_22 (Dropout)        (None, 1024)              0
#
#  dense_28 (Dense)            (None, 512)               524800
#
#  dropout_23 (Dropout)        (None, 512)               0
#
#  dense_29 (Dense)            (None, 123)               63099
#
# =================================================================
# Total params: 1343355 (5.12 MB)
# Trainable params: 1343355 (5.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model2.fit(train_embeddings, Y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 1261/1261 [==============================] - 6s 3ms/step - loss: 1.8788 - accuracy: 0.4882
# Epoch 2/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.3227 - accuracy: 0.6051
# Epoch 3/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.1769 - accuracy: 0.6406
# Epoch 4/20
# 1261/1261 [==============================] - 4s 4ms/step - loss: 1.0758 - accuracy: 0.6622
# Epoch 5/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.9927 - accuracy: 0.6830
# Epoch 6/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.9296 - accuracy: 0.6993
# Epoch 7/20
# 1261/1261 [==============================] - 4s 4ms/step - loss: 0.8753 - accuracy: 0.7157
# Epoch 8/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.8276 - accuracy: 0.7263
# Epoch 9/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.7798 - accuracy: 0.7397
# Epoch 10/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.7486 - accuracy: 0.7498
# Epoch 11/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.7081 - accuracy: 0.7625
# Epoch 12/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.6851 - accuracy: 0.7693
# Epoch 13/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.6581 - accuracy: 0.7775
# Epoch 14/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.6314 - accuracy: 0.7836
# Epoch 15/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.6107 - accuracy: 0.7913
# Epoch 16/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.5934 - accuracy: 0.7959
# Epoch 17/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.5722 - accuracy: 0.8028
# Epoch 18/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.5610 - accuracy: 0.8077
# Epoch 19/20
# 1261/1261 [==============================] - 4s 3ms/step - loss: 0.5453 - accuracy: 0.8142
# Epoch 20/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.5303 - accuracy: 0.8185

# %%
y_pred_prob = model2.predict(test_embeddings)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 271/271 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.6598057354301573
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.59      0.64      0.61        99
#            1       0.78      0.74      0.76       126
#            2       0.57      0.66      0.61       130
#            3       0.75      0.75      0.75        12
#            4       0.51      0.41      0.45       118
#            5       0.23      0.23      0.23        30
#            6       0.38      0.43      0.41       104
#            7       0.27      0.33      0.30         9
#            8       0.58      0.44      0.50       557
#            9       0.08      0.18      0.11        11
#           10       0.67      0.67      0.67       225
#           11       0.00      0.00      0.00         3
#           12       0.75      0.84      0.79       189
#           13       0.44      0.45      0.45        42
#           14       0.00      0.00      0.00         3
#           15       0.50      0.22      0.31         9
#           16       0.00      0.00      0.00         2
#           17       0.63      0.73      0.68        37
#           18       0.00      0.00      0.00         1
#           19       0.50      0.20      0.29         5
#           20       0.67      0.41      0.51        34
#           21       0.14      0.11      0.12         9
#           22       0.36      0.36      0.36        11
#           23       0.73      0.76      0.74       167
#           24       0.00      0.00      0.00         9
#           25       0.64      0.55      0.59        29
#           26       0.80      0.60      0.69        20
#           27       0.41      0.24      0.30       100
#           28       0.84      0.86      0.85       268
#           29       0.65      0.63      0.64        27
#           30       0.16      0.21      0.18        24
#           31       0.47      0.40      0.43       179
#           32       0.56      0.26      0.36        19
#           33       0.56      0.44      0.49       135
#           34       0.67      0.58      0.62       180
#           35       0.82      0.81      0.82        69
#           36       0.00      0.00      0.00         4
#           37       0.53      0.49      0.51        53
#           38       0.61      0.63      0.62        87
#           39       0.17      0.50      0.25         4
#           40       0.82      0.72      0.77       180
#           41       0.82      0.74      0.78       272
#           42       0.65      0.65      0.65        20
#           43       0.77      0.91      0.83        33
#           44       0.14      0.25      0.18         4
#           45       0.00      0.00      0.00         5
#           46       0.38      0.40      0.39        20
#           47       0.40      0.14      0.21        14
#           49       0.37      0.41      0.39        34
#           50       0.56      0.33      0.42        15
#           51       0.48      0.70      0.57       175
#           52       0.61      0.70      0.66        61
#           53       0.50      0.25      0.33         4
#           54       0.74      0.80      0.77       215
#           55       0.60      0.43      0.50         7
#           56       0.75      0.50      0.60         6
#           57       0.58      0.54      0.56        13
#           58       0.29      0.17      0.21        12
#           59       0.33      0.50      0.39        26
#           60       0.15      0.22      0.18         9
#           61       0.86      0.63      0.73        60
#           62       0.50      0.17      0.25        18
#           63       0.54      0.61      0.57        84
#           64       0.50      0.42      0.45        24
#           65       0.62      0.71      0.67         7
#           66       0.62      0.57      0.60        35
#           67       0.49      0.40      0.44        77
#           68       0.66      0.63      0.64       235
#           69       0.00      0.00      0.00         1
#           70       0.54      0.62      0.58       151
#           71       0.33      0.30      0.32        10
#           72       0.29      0.40      0.33         5
#           73       0.85      0.80      0.82        93
#           74       0.31      0.36      0.33        14
#           75       0.87      0.83      0.85        24
#           76       0.58      0.64      0.61        11
#           77       0.88      0.88      0.88        49
#           78       0.31      0.44      0.36         9
#           79       0.67      0.67      0.67         3
#           80       0.58      0.39      0.47        18
#           81       0.00      0.00      0.00         1
#           82       0.69      0.73      0.71        15
#           83       0.50      0.17      0.25         6
#           84       0.61      0.65      0.63       209
#           85       0.73      0.71      0.72       104
#           86       0.62      0.64      0.63        53
#           87       0.00      0.00      0.00         1
#           88       0.95      0.95      0.95        19
#           89       0.78      1.00      0.88         7
#           90       0.55      0.79      0.65        33
#           91       0.75      0.73      0.74       104
#           92       0.00      0.00      0.00         1
#           93       0.46      0.68      0.55       138
#           94       0.00      0.00      0.00         4
#           95       0.79      0.78      0.78       933
#           96       0.33      0.44      0.38         9
#           97       0.36      0.39      0.37        23
#           98       0.68      0.53      0.60        49
#           99       0.00      0.00      0.00         7
#          100       0.67      0.48      0.56        21
#          101       0.55      0.64      0.59        36
#          102       0.00      0.00      0.00         2
#          103       0.62      0.83      0.71        30
#          104       1.00      0.58      0.74        12
#          105       0.17      0.29      0.21         7
#          106       0.25      0.29      0.27         7
#          107       0.78      0.87      0.82       812
#          108       0.82      0.81      0.82        63
#          109       0.88      1.00      0.93         7
#          110       0.60      1.00      0.75         3
#          111       0.70      0.80      0.75        55
#          112       0.61      0.42      0.50        45
#          113       0.60      0.16      0.25        19
#          114       0.60      0.43      0.50         7
#          115       0.76      0.78      0.77        95
#          116       0.67      0.33      0.44         6
#          117       0.67      0.62      0.65        56
#          118       0.70      0.76      0.73       130
#          119       0.64      0.72      0.68       233
#          120       0.54      0.55      0.54        80
#          121       0.00      0.00      0.00         2
#          122       0.91      0.91      0.91        11
#
#     accuracy                           0.66      8648
#    macro avg       0.50      0.48      0.48      8648
# weighted avg       0.66      0.66      0.66      8648

# %%
## Model 3
model3 = tf.keras.Sequential([
    tf.keras.layers.Dense(512, activation='relu', input_shape=(input_dim,)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(2016, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(1280, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

# Compile the model
model3.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Print model summary
model3.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 512)               197120
#
#  dropout_24 (Dropout)        (None, 512)               0
#
#  dense_31 (Dense)            (None, 1024)              525312
#
#  dropout_25 (Dropout)        (None, 1024)              0
#
#  dense_32 (Dense)            (None, 2016)              2066400
#
#  dropout_26 (Dropout)        (None, 2016)              0
#
#  dense_33 (Dense)            (None, 1280)              2581760
#
#  dropout_27 (Dropout)        (None, 1280)              0
#
#  dense_34 (Dense)            (None, 512)               655872
#
#  dropout_28 (Dropout)        (None, 512)               0
#
#  dense_35 (Dense)            (None, 256)               131328
#
#  dropout_29 (Dropout)        (None, 256)               0
#
#  dense_36 (Dense)            (None, 123)               31611
#
# =================================================================
# Total params: 6189403 (23.61 MB)
# Trainable params: 6189403 (23.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model3.fit(train_embeddings, Y_train, epochs=20, batch_size=32)
# Out:
# Epoch 1/20
# 1261/1261 [==============================] - 8s 4ms/step - loss: 2.2219 - accuracy: 0.4031
# Epoch 2/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.5570 - accuracy: 0.5632
# Epoch 3/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.3560 - accuracy: 0.6117
# Epoch 4/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.2437 - accuracy: 0.6393
# Epoch 5/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.1404 - accuracy: 0.6635
# Epoch 6/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 1.0620 - accuracy: 0.6808
# Epoch 7/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.9995 - accuracy: 0.6977
# Epoch 8/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.9334 - accuracy: 0.7156
# Epoch 9/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.8867 - accuracy: 0.7265
# Epoch 10/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.8454 - accuracy: 0.7395
# Epoch 11/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.8102 - accuracy: 0.7479
# Epoch 12/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7742 - accuracy: 0.7603
# Epoch 13/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7493 - accuracy: 0.7677
# Epoch 14/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7239 - accuracy: 0.7782
# Epoch 15/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.7030 - accuracy: 0.7798
# Epoch 16/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.6699 - accuracy: 0.7931
# Epoch 17/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.6594 - accuracy: 0.7964
# Epoch 18/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.6343 - accuracy: 0.8062
# Epoch 19/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.6288 - accuracy: 0.8076
# Epoch 20/20
# 1261/1261 [==============================] - 5s 4ms/step - loss: 0.6145 - accuracy: 0.8125

# %%
y_pred_prob = model3.predict(test_embeddings)
y_pred = np.argmax(y_pred_prob, axis=1)

from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# 271/271 [==============================] - 1s 3ms/step
# Accuracy:  0.6675531914893617
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.71      0.70        99
#            1       0.80      0.71      0.76       126
#            2       0.60      0.65      0.63       130
#            3       0.85      0.92      0.88        12
#            4       0.55      0.42      0.48       118
#            5       0.25      0.20      0.22        30
#            6       0.58      0.27      0.37       104
#            7       0.25      0.11      0.15         9
#            8       0.52      0.62      0.56       557
#            9       0.38      0.27      0.32        11
#           10       0.62      0.69      0.66       225
#           11       1.00      0.33      0.50         3
#           12       0.83      0.80      0.81       189
#           13       0.54      0.52      0.53        42
#           14       0.00      0.00      0.00         3
#           15       0.50      0.44      0.47         9
#           16       0.00      0.00      0.00         2
#           17       0.62      0.89      0.73        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.64      0.47      0.54        34
#           21       0.20      0.22      0.21         9
#           22       0.58      0.64      0.61        11
#           23       0.71      0.90      0.80       167
#           24       0.07      0.11      0.09         9
#           25       0.50      0.48      0.49        29
#           26       0.67      0.70      0.68        20
#           27       0.33      0.36      0.35       100
#           28       0.84      0.85      0.85       268
#           29       0.81      0.63      0.71        27
#           30       0.13      0.29      0.18        24
#           31       0.46      0.40      0.43       179
#           32       0.44      0.21      0.29        19
#           33       0.58      0.44      0.50       135
#           34       0.70      0.58      0.64       180
#           35       0.75      0.80      0.77        69
#           36       0.00      0.00      0.00         4
#           37       0.52      0.53      0.52        53
#           38       0.62      0.52      0.57        87
#           39       0.09      0.25      0.13         4
#           40       0.73      0.83      0.78       180
#           41       0.79      0.70      0.74       272
#           42       0.91      0.50      0.65        20
#           43       0.82      0.94      0.87        33
#           44       0.00      0.00      0.00         4
#           45       0.25      0.20      0.22         5
#           46       0.48      0.55      0.51        20
#           47       0.50      0.07      0.12        14
#           49       0.40      0.41      0.41        34
#           50       0.53      0.60      0.56        15
#           51       0.55      0.50      0.52       175
#           52       0.70      0.74      0.72        61
#           53       0.67      0.50      0.57         4
#           54       0.73      0.80      0.76       215
#           55       1.00      0.43      0.60         7
#           56       0.60      0.50      0.55         6
#           57       0.64      0.69      0.67        13
#           58       0.43      0.25      0.32        12
#           59       0.33      0.38      0.36        26
#           60       0.25      0.11      0.15         9
#           61       0.88      0.58      0.70        60
#           62       0.50      0.11      0.18        18
#           63       0.61      0.64      0.63        84
#           64       0.43      0.54      0.48        24
#           65       0.58      1.00      0.74         7
#           66       0.65      0.63      0.64        35
#           67       0.51      0.49      0.50        77
#           68       0.75      0.50      0.60       235
#           69       0.00      0.00      0.00         1
#           70       0.57      0.60      0.58       151
#           71       0.14      0.10      0.12        10
#           72       0.00      0.00      0.00         5
#           73       0.80      0.80      0.80        93
#           74       0.33      0.21      0.26        14
#           75       0.86      0.79      0.83        24
#           76       0.50      0.18      0.27        11
#           77       0.93      0.88      0.91        49
#           78       0.33      0.22      0.27         9
#           79       0.00      0.00      0.00         3
#           80       1.00      0.28      0.43        18
#           81       0.00      0.00      0.00         1
#           82       0.76      0.87      0.81        15
#           83       0.50      0.33      0.40         6
#           84       0.68      0.62      0.65       209
#           85       0.64      0.81      0.71       104
#           86       0.60      0.53      0.56        53
#           87       0.00      0.00      0.00         1
#           88       0.95      0.95      0.95        19
#           89       0.83      0.71      0.77         7
#           90       0.79      0.70      0.74        33
#           91       0.69      0.73      0.71       104
#           92       0.00      0.00      0.00         1
#           93       0.67      0.28      0.39       138
#           94       0.00      0.00      0.00         4
#           95       0.77      0.82      0.79       933
#           96       0.36      0.56      0.43         9
#           97       0.26      0.22      0.24        23
#           98       0.58      0.80      0.67        49
#           99       0.00      0.00      0.00         7
#          100       0.52      0.52      0.52        21
#          101       0.51      0.53      0.52        36
#          102       0.22      1.00      0.36         2
#          103       0.57      0.87      0.68        30
#          104       0.64      0.58      0.61        12
#          105       0.06      0.14      0.08         7
#          106       0.00      0.00      0.00         7
#          107       0.81      0.89      0.85       812
#          108       0.82      0.81      0.82        63
#          109       0.75      0.86      0.80         7
#          110       0.43      1.00      0.60         3
#          111       0.66      0.75      0.70        55
#          112       0.66      0.56      0.60        45
#          113       0.67      0.11      0.18        19
#          114       0.60      0.43      0.50         7
#          115       0.66      0.82      0.73        95
#          116       0.00      0.00      0.00         6
#          117       0.48      0.66      0.56        56
#          118       0.80      0.75      0.77       130
#          119       0.63      0.68      0.66       233
#          120       0.55      0.59      0.57        80
#          121       0.00      0.00      0.00         2
#          122       0.92      1.00      0.96        11
#
#     accuracy                           0.67      8648
#    macro avg       0.51      0.48      0.48      8648
# weighted avg       0.67      0.67      0.66      8648

# %% [markdown]
# ## XGBOOST

# %%
import xgboost as xgb

dtrain = xgb.DMatrix(train_embeddings, label=Y_train)
dtest = xgb.DMatrix(test_embeddings, label=Y_test)

# Define XGBoost parameters
param = {
    'objective': 'multi:softmax',
    'num_class': 123,
    'max_depth': 6,
    'eta': 0.3,
    'eval_metric': 'merror'
}

# Train the XGBoost model
num_round = 100
bst = xgb.train(param, dtrain, num_round)

# Predict the labels of the test set
xg_y_pred = bst.predict(dtest)

# %%
xg_y_pred
# Out:
# array([ 51., 107.,  68., ...,  84.,  27.,  77.], dtype=float32)

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(xg_y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, xg_y_pred))
# Out:
# Accuracy:  0.5883441258094357
#
# -----------------------------------------------
#
#
#
#
#
#               precision    recall  f1-score   support
#
#
#
#            0       0.55      0.47      0.51        99
#
#            1       0.65      0.67      0.66       126
#
#            2       0.59      0.55      0.57       130
#
#            3       0.82      0.75      0.78        12
#
#            4       0.44      0.39      0.41       118
#
#            5       0.20      0.13      0.16        30
#
#            6       0.36      0.35      0.35       104
#
#            7       0.60      0.33      0.43         9
#
#            8       0.47      0.60      0.52       557
#
#            9       0.25      0.09      0.13        11
#
#           10       0.56      0.49      0.52       225
#
#           11       0.50      0.33      0.40         3
#
#           12       0.63      0.79      0.70       189
#
#           13       0.47      0.19      0.27        42
#
#           14       0.00      0.00      0.00         3
#
#           15       0.38      0.33      0.35         9
#
#           16       0.00      0.00      0.00         2
#
#           17       0.72      0.62      0.67        37
#
#           18       0.00      0.00      0.00         1
#
#           19       0.00      0.00      0.00         5
#
#           20       0.48      0.32      0.39        34
#
#           21       0.00      0.00      0.00         9
#
#           22       0.71      0.45      0.56        11
#
#           23       0.64      0.74      0.68       167
#
#           24       0.00      0.00      0.00         9
#
#           25       0.52      0.41      0.46        29
#
#           26       0.63      0.60      0.62        20
#
#           27       0.31      0.21      0.25       100
#
#           28       0.76      0.81      0.78       268
#
#           29       0.61      0.52      0.56        27
#
#           30       0.32      0.38      0.35        24
#
#           31       0.39      0.35      0.37       179
#
#           32       0.50      0.26      0.34        19
#
#           33       0.45      0.27      0.34       135
#
#           34       0.53      0.54      0.54       180
#
#           35       0.71      0.77      0.74        69
#
#           36       0.00      0.00      0.00         4
#
#           37       0.48      0.40      0.43        53
#
#           38       0.50      0.60      0.54        87
#
#           39       0.14      0.25      0.18         4
#
#           40       0.68      0.72      0.70       180
#
#           41       0.65      0.65      0.65       272
#
#           42       0.91      0.50      0.65        20
#
#           43       0.79      0.91      0.85        33
#
#           44       0.00      0.00      0.00         4
#
#           45       0.00      0.00      0.00         5
#
#           46       0.53      0.50      0.51        20
#
#           47       0.50      0.14      0.22        14
#
#           49       0.59      0.38      0.46        34
#
#           50       0.50      0.53      0.52        15
#
#           51       0.50      0.33      0.40       175
#
#           52       0.65      0.54      0.59        61
#
#           53       0.33      0.25      0.29         4
#
#           54       0.61      0.66      0.64       215
#
#           55       0.33      0.29      0.31         7
#
#           56       1.00      0.33      0.50         6
#
#           57       0.75      0.46      0.57        13
#
#           58       0.00      0.00      0.00        12
#
#           59       0.29      0.31      0.30        26
#
#           60       0.33      0.11      0.17         9
#
#           61       0.60      0.62      0.61        60
#
#           62       0.43      0.33      0.38        18
#
#           63       0.62      0.43      0.51        84
#
#           64       0.47      0.33      0.39        24
#
#           65       1.00      0.29      0.44         7
#
#           66       0.77      0.69      0.73        35
#
#           67       0.45      0.60      0.51        77
#
#           68       0.52      0.57      0.54       235
#
#           69       0.00      0.00      0.00         1
#
#           70       0.39      0.43      0.41       151
#
#           71       0.25      0.10      0.14        10
#
#           72       0.00      0.00      0.00         5
#
#           73       0.73      0.71      0.72        93
#
#           74       0.50      0.14      0.22        14
#
#           75       0.78      0.58      0.67        24
#
#           76       1.00      0.36      0.53        11
#
#           77       0.88      0.78      0.83        49
#
#           78       0.29      0.22      0.25         9
#
#           79       0.00      0.00      0.00         3
#
#           80       0.88      0.39      0.54        18
#
#           81       0.00      0.00      0.00         1
#
#           82       0.77      0.67      0.71        15
#
#           83       0.50      0.17      0.25         6
#
#           84       0.58      0.43      0.49       209
#
#           85       0.70      0.76      0.73       104
#
#           86       0.55      0.55      0.55        53
#
#           87       0.00      0.00      0.00         1
#
#           88       1.00      0.84      0.91        19
#
#           89       0.86      0.86      0.86         7
#
#           90       0.69      0.82      0.75        33
#
#           91       0.67      0.63      0.65       104
#
#           92       0.00      0.00      0.00         1
#
#           93       0.50      0.43      0.46       138
#
#           94       0.00      0.00      0.00         4
#
#           95       0.61      0.77      0.68       933
#
#           96       0.75      0.67      0.71         9
#
#           97       0.20      0.09      0.12        23
#
#           98       0.73      0.45      0.56        49
#
#           99       0.00      0.00      0.00         7
#
#          100       0.78      0.33      0.47        21
#
#          101       0.40      0.22      0.29        36
#
#          102       0.00      0.00      0.00         2
#
#          103       0.68      0.63      0.66        30
#
#          104       1.00      0.25      0.40        12
#
#          105       0.29      0.29      0.29         7
#
#          106       0.00      0.00      0.00         7
#
#          107       0.73      0.79      0.76       812
#
#          108       0.71      0.73      0.72        63
#
#          109       0.86      0.86      0.86         7
#
#          110       0.67      0.67      0.67         3
#
#          111       0.70      0.60      0.65        55
#
#          112       0.53      0.47      0.49        45
#
#          113       0.88      0.37      0.52        19
#
#          114       0.25      0.14      0.18         7
#
#          115       0.73      0.72      0.72        95
#
#          116       0.00      0.00      0.00         6
#
#          117       0.44      0.46      0.45        56
#
#          118       0.60      0.68      0.64       130
#
#          119       0.56      0.56      0.56       233
#
#          120       0.37      0.39      0.38        80
#
#          121       0.00      0.00      0.00         2
#
#          122       1.00      0.82      0.90        11
#
#
#
#     accuracy                           0.59      8648
#
#    macro avg       0.48      0.40      0.42      8648
#
# weighted avg       0.58      0.59      0.58      8648

# %%
## final model
from sklearn.svm import SVC
svm = SVC(C=1.5, kernel = 'poly')

svm.fit(train_embeddings,Y_train)
y_pred = svm.predict(test_embeddings)

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.7161193339500462
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.71      0.72        99
#            1       0.79      0.79      0.79       126
#            2       0.63      0.69      0.66       130
#            3       0.92      1.00      0.96        12
#            4       0.68      0.57      0.62       118
#            5       0.27      0.13      0.18        30
#            6       0.56      0.52      0.54       104
#            7       1.00      0.44      0.62         9
#            8       0.56      0.69      0.62       557
#            9       1.00      0.18      0.31        11
#           10       0.71      0.70      0.70       225
#           11       0.00      0.00      0.00         3
#           12       0.63      0.93      0.75       189
#           13       0.73      0.38      0.50        42
#           14       0.00      0.00      0.00         3
#           15       0.75      0.67      0.71         9
#           16       0.00      0.00      0.00         2
#           17       0.86      0.84      0.85        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.79      0.44      0.57        34
#           21       1.00      0.11      0.20         9
#           22       0.67      0.36      0.47        11
#           23       0.74      0.91      0.82       167
#           24       0.00      0.00      0.00         9
#           25       0.70      0.48      0.57        29
#           26       0.72      0.65      0.68        20
#           27       0.44      0.32      0.37       100
#           28       0.83      0.93      0.88       268
#           29       0.95      0.67      0.78        27
#           30       0.24      0.21      0.22        24
#           31       0.54      0.44      0.48       179
#           32       0.50      0.11      0.17        19
#           33       0.71      0.38      0.49       135
#           34       0.69      0.74      0.71       180
#           35       0.80      0.83      0.81        69
#           36       0.00      0.00      0.00         4
#           37       0.56      0.57      0.56        53
#           38       0.55      0.71      0.62        87
#           39       0.33      0.25      0.29         4
#           40       0.78      0.83      0.81       180
#           41       0.81      0.80      0.80       272
#           42       0.92      0.60      0.73        20
#           43       0.94      0.88      0.91        33
#           44       0.00      0.00      0.00         4
#           45       0.00      0.00      0.00         5
#           46       0.52      0.70      0.60        20
#           47       0.67      0.14      0.24        14
#           49       0.57      0.47      0.52        34
#           50       0.75      0.60      0.67        15
#           51       0.70      0.54      0.61       175
#           52       0.78      0.77      0.78        61
#           53       0.00      0.00      0.00         4
#           54       0.77      0.86      0.81       215
#           55       1.00      0.57      0.73         7
#           56       1.00      0.50      0.67         6
#           57       1.00      0.38      0.56        13
#           58       0.00      0.00      0.00        12
#           59       0.59      0.38      0.47        26
#           60       1.00      0.11      0.20         9
#           61       0.84      0.70      0.76        60
#           62       0.70      0.39      0.50        18
#           63       0.75      0.58      0.66        84
#           64       0.62      0.54      0.58        24
#           65       1.00      0.86      0.92         7
#           66       0.75      0.69      0.72        35
#           67       0.54      0.66      0.59        77
#           68       0.67      0.70      0.69       235
#           69       1.00      1.00      1.00         1
#           70       0.59      0.68      0.63       151
#           71       1.00      0.10      0.18        10
#           72       0.00      0.00      0.00         5
#           73       0.80      0.86      0.83        93
#           74       0.67      0.29      0.40        14
#           75       0.96      0.92      0.94        24
#           76       1.00      0.45      0.62        11
#           77       0.96      0.88      0.91        49
#           78       0.50      0.33      0.40         9
#           79       0.00      0.00      0.00         3
#           80       0.82      0.50      0.62        18
#           81       0.00      0.00      0.00         1
#           82       0.76      0.87      0.81        15
#           83       0.67      0.33      0.44         6
#           84       0.73      0.63      0.68       209
#           85       0.79      0.80      0.79       104
#           86       0.70      0.66      0.68        53
#           87       0.00      0.00      0.00         1
#           88       0.95      1.00      0.97        19
#           89       1.00      1.00      1.00         7
#           90       0.80      0.85      0.82        33
#           91       0.77      0.76      0.77       104
#           92       0.00      0.00      0.00         1
#           93       0.57      0.49      0.53       138
#           94       1.00      0.25      0.40         4
#           95       0.72      0.87      0.79       933
#           96       0.62      0.56      0.59         9
#           97       0.44      0.30      0.36        23
#           98       0.82      0.63      0.71        49
#           99       0.00      0.00      0.00         7
#          100       0.85      0.52      0.65        21
#          101       0.64      0.39      0.48        36
#          102       0.25      0.50      0.33         2
#          103       0.81      0.73      0.77        30
#          104       0.86      0.50      0.63        12
#          105       0.20      0.29      0.24         7
#          106       0.00      0.00      0.00         7
#          107       0.87      0.88      0.87       812
#          108       0.83      0.92      0.87        63
#          109       0.86      0.86      0.86         7
#          110       0.75      1.00      0.86         3
#          111       0.77      0.78      0.77        55
#          112       0.70      0.47      0.56        45
#          113       0.75      0.16      0.26        19
#          114       0.80      0.57      0.67         7
#          115       0.77      0.85      0.81        95
#          116       1.00      0.17      0.29         6
#          117       0.67      0.73      0.70        56
#          118       0.76      0.79      0.77       130
#          119       0.72      0.69      0.70       233
#          120       0.57      0.66      0.61        80
#          121       0.00      0.00      0.00         2
#          122       1.00      0.82      0.90        11
#
#     accuracy                           0.72      8648
#    macro avg       0.63      0.51      0.53      8648
# weighted avg       0.71      0.72      0.71      8648

# %%
final_model = svm

# %%
import pickle

with open('final_model.pkl', 'wb') as f:
    pickle.dump(final_model, f)

# %%
import tensorflow as tf

input_dim = 384
num_classes = 123
y_train_one_hot = tf.keras.utils.to_categorical(Y_train, num_classes)


def focal_loss(y_true, y_pred, gamma=2.0, alpha=0.25):
    epsilon = 1e-8
    y_pred = tf.clip_by_value(y_pred, epsilon, 1.0 - epsilon)
    pt = tf.where(tf.equal(y_true, 1), y_pred, 1 - y_pred)
    focal_loss = -tf.reduce_sum(alpha * tf.pow(1.0 - pt, gamma) * tf.math.log(pt))
    return focal_loss

model4 = tf.keras.Sequential([
    tf.keras.layers.Dense(256, activation='relu', input_shape=(input_dim,)),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])
model4.compile(optimizer='adam',
              loss= focal_loss,
             metrics=['accuracy'])

model4.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_37 (Dense)            (None, 256)               98560
#
#  dropout_30 (Dropout)        (None, 256)               0
#
#  dense_38 (Dense)            (None, 512)               131584
#
#  dropout_31 (Dropout)        (None, 512)               0
#
#  dense_39 (Dense)            (None, 256)               131328
#
#  dropout_32 (Dropout)        (None, 256)               0
#
#  dense_40 (Dense)            (None, 128)               32896
#
#  dropout_33 (Dropout)        (None, 128)               0
#
#  dense_41 (Dense)            (None, 123)               15867
#
# =================================================================
# Total params: 410235 (1.56 MB)
# Trainable params: 410235 (1.56 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model4.fit(train_embeddings, y_train_one_hot, epochs=25, batch_size=16)
# Out:
# Epoch 1/25
# 2521/2521 [==============================] - 12s 4ms/step - loss: 6.6704 - accuracy: 0.4574
# Epoch 2/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 4.4261 - accuracy: 0.5753
# Epoch 3/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 3.8298 - accuracy: 0.6123
# Epoch 4/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 3.4663 - accuracy: 0.6326
# Epoch 5/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 3.2112 - accuracy: 0.6485
# Epoch 6/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.9791 - accuracy: 0.6616
# Epoch 7/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.8300 - accuracy: 0.6716
# Epoch 8/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.6617 - accuracy: 0.6820
# Epoch 9/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.5469 - accuracy: 0.6904
# Epoch 10/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.4419 - accuracy: 0.6998
# Epoch 11/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.3490 - accuracy: 0.7066
# Epoch 12/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.2990 - accuracy: 0.7086
# Epoch 13/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.2358 - accuracy: 0.7157
# Epoch 14/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.1441 - accuracy: 0.7242
# Epoch 15/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.1176 - accuracy: 0.7272
# Epoch 16/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.0912 - accuracy: 0.7302
# Epoch 17/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.0139 - accuracy: 0.7356
# Epoch 18/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 2.0030 - accuracy: 0.7374
# Epoch 19/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 1.9899 - accuracy: 0.7396
# Epoch 20/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 1.9371 - accuracy: 0.7428
# Epoch 21/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 1.9279 - accuracy: 0.7455
# Epoch 22/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 1.9223 - accuracy: 0.7451
# Epoch 23/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 1.8951 - accuracy: 0.7486
# Epoch 24/25
# 2521/2521 [==============================] - 9s 4ms/step - loss: 1.8640 - accuracy: 0.7515
# Epoch 25/25
# 2521/2521 [==============================] - 9s 3ms/step - loss: 1.8457 - accuracy: 0.7544

# %%
y_pred_prob = model4.predict(test_embeddings)
y_pred = np.argmax(y_pred_prob, axis=1)

from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# 271/271 [==============================] - 0s 1ms/step
# Accuracy:  0.651827012025902
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.21      0.33        99
#            1       0.72      0.75      0.74       126
#            2       0.58      0.65      0.62       130
#            3       0.79      0.92      0.85        12
#            4       0.46      0.56      0.51       118
#            5       0.27      0.13      0.18        30
#            6       0.42      0.26      0.32       104
#            7       0.38      0.56      0.45         9
#            8       0.52      0.52      0.52       557
#            9       0.67      0.18      0.29        11
#           10       0.61      0.71      0.65       225
#           11       0.00      0.00      0.00         3
#           12       0.76      0.84      0.80       189
#           13       0.51      0.45      0.48        42
#           14       0.00      0.00      0.00         3
#           15       0.46      0.67      0.55         9
#           16       0.00      0.00      0.00         2
#           17       0.70      0.70      0.70        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.50      0.47      0.48        34
#           21       0.00      0.00      0.00         9
#           22       0.44      0.36      0.40        11
#           23       0.68      0.89      0.77       167
#           24       0.11      0.11      0.11         9
#           25       0.43      0.41      0.42        29
#           26       0.62      0.50      0.56        20
#           27       0.28      0.17      0.21       100
#           28       0.79      0.88      0.84       268
#           29       0.76      0.59      0.67        27
#           30       0.17      0.33      0.22        24
#           31       0.52      0.32      0.40       179
#           32       0.23      0.16      0.19        19
#           33       0.54      0.50      0.52       135
#           34       0.64      0.66      0.65       180
#           35       0.70      0.83      0.75        69
#           36       0.00      0.00      0.00         4
#           37       0.47      0.36      0.41        53
#           38       0.49      0.57      0.53        87
#           39       0.14      0.25      0.18         4
#           40       0.77      0.76      0.76       180
#           41       0.83      0.67      0.74       272
#           42       0.77      0.50      0.61        20
#           43       0.81      0.88      0.84        33
#           44       0.00      0.00      0.00         4
#           45       0.25      0.20      0.22         5
#           46       0.45      0.50      0.48        20
#           47       0.25      0.07      0.11        14
#           49       0.42      0.41      0.42        34
#           50       0.53      0.67      0.59        15
#           51       0.57      0.42      0.48       175
#           52       0.72      0.70      0.71        61
#           53       0.25      0.25      0.25         4
#           54       0.76      0.81      0.79       215
#           55       0.67      0.57      0.62         7
#           56       0.50      0.67      0.57         6
#           57       1.00      0.46      0.63        13
#           58       0.25      0.08      0.12        12
#           59       0.28      0.31      0.29        26
#           60       0.20      0.11      0.14         9
#           61       0.68      0.63      0.66        60
#           62       0.30      0.17      0.21        18
#           63       0.58      0.56      0.57        84
#           64       0.38      0.33      0.36        24
#           65       0.86      0.86      0.86         7
#           66       0.57      0.69      0.62        35
#           67       0.44      0.47      0.46        77
#           68       0.62      0.72      0.67       235
#           69       0.33      1.00      0.50         1
#           70       0.46      0.61      0.52       151
#           71       0.20      0.20      0.20        10
#           72       0.00      0.00      0.00         5
#           73       0.74      0.84      0.78        93
#           74       0.27      0.21      0.24        14
#           75       0.91      0.83      0.87        24
#           76       0.50      0.09      0.15        11
#           77       0.91      0.86      0.88        49
#           78       0.31      0.44      0.36         9
#           79       0.00      0.00      0.00         3
#           80       0.62      0.44      0.52        18
#           81       0.00      0.00      0.00         1
#           82       0.71      0.80      0.75        15
#           83       0.29      0.33      0.31         6
#           84       0.67      0.61      0.64       209
#           85       0.64      0.80      0.71       104
#           86       0.53      0.55      0.54        53
#           87       0.00      0.00      0.00         1
#           88       0.95      1.00      0.97        19
#           89       0.78      1.00      0.88         7
#           90       0.65      0.73      0.69        33
#           91       0.62      0.72      0.67       104
#           92       0.00      0.00      0.00         1
#           93       0.54      0.47      0.50       138
#           94       0.50      0.25      0.33         4
#           95       0.81      0.76      0.79       933
#           96       0.50      0.67      0.57         9
#           97       0.12      0.09      0.10        23
#           98       0.68      0.65      0.67        49
#           99       0.00      0.00      0.00         7
#          100       0.82      0.43      0.56        21
#          101       0.54      0.42      0.47        36
#          102       0.20      1.00      0.33         2
#          103       0.64      0.83      0.72        30
#          104       0.60      0.25      0.35        12
#          105       0.17      0.43      0.24         7
#          106       0.00      0.00      0.00         7
#          107       0.82      0.87      0.85       812
#          108       0.79      0.79      0.79        63
#          109       0.64      1.00      0.78         7
#          110       0.33      0.67      0.44         3
#          111       0.80      0.58      0.67        55
#          112       0.59      0.44      0.51        45
#          113       0.00      0.00      0.00        19
#          114       0.75      0.43      0.55         7
#          115       0.75      0.74      0.74        95
#          116       1.00      0.17      0.29         6
#          117       0.61      0.66      0.63        56
#          118       0.69      0.72      0.70       130
#          119       0.58      0.79      0.67       233
#          120       0.48      0.62      0.54        80
#          121       0.33      0.50      0.40         2
#          122       0.73      1.00      0.85        11
#
#     accuracy                           0.65      8648
#    macro avg       0.48      0.48      0.46      8648
# weighted avg       0.65      0.65      0.64      8648

# %%
##------------------------------------------------------------------------------------------------------------------------------

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_classifier = KNeighborsClassifier(n_neighbors=10)
knn_classifier.fit(train_embeddings, Y_train)
y_pred = knn_classifier.predict(test_embeddings)

# %%
y_pred
# Out:
# array([ 33, 107,  10, ...,  10,  27,  77])

# %%
from sklearn.metrics import classification_report, accuracy_score
print("Accuracy: ", accuracy_score(y_pred,Y_test))
print("-----------------------------------------------\n\n")
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy:  0.6983117483811286
# -----------------------------------------------
#
#
#               precision    recall  f1-score   support
#
#            0       0.72      0.69      0.70        99
#            1       0.76      0.81      0.78       126
#            2       0.65      0.66      0.65       130
#            3       0.80      1.00      0.89        12
#            4       0.53      0.53      0.53       118
#            5       0.18      0.10      0.13        30
#            6       0.53      0.48      0.50       104
#            7       0.60      0.33      0.43         9
#            8       0.50      0.64      0.56       557
#            9       0.00      0.00      0.00        11
#           10       0.64      0.73      0.68       225
#           11       0.00      0.00      0.00         3
#           12       0.76      0.88      0.82       189
#           13       0.59      0.38      0.46        42
#           14       0.00      0.00      0.00         3
#           15       0.60      0.67      0.63         9
#           16       0.00      0.00      0.00         2
#           17       0.82      0.89      0.86        37
#           18       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         5
#           20       0.81      0.50      0.62        34
#           21       0.17      0.11      0.13         9
#           22       0.58      0.64      0.61        11
#           23       0.67      0.86      0.76       167
#           24       0.00      0.00      0.00         9
#           25       0.57      0.72      0.64        29
#           26       0.47      0.70      0.56        20
#           27       0.44      0.32      0.37       100
#           28       0.79      0.95      0.86       268
#           29       0.80      0.74      0.77        27
#           30       0.12      0.08      0.10        24
#           31       0.56      0.45      0.50       179
#           32       0.38      0.26      0.31        19
#           33       0.62      0.35      0.45       135
#           34       0.66      0.78      0.72       180
#           35       0.65      0.77      0.70        69
#           36       0.00      0.00      0.00         4
#           37       0.53      0.53      0.53        53
#           38       0.56      0.66      0.61        87
#           39       0.00      0.00      0.00         4
#           40       0.76      0.86      0.81       180
#           41       0.83      0.82      0.82       272
#           42       1.00      0.55      0.71        20
#           43       0.76      0.94      0.84        33
#           44       0.00      0.00      0.00         4
#           45       0.00      0.00      0.00         5
#           46       0.43      0.60      0.50        20
#           47       0.40      0.14      0.21        14
#           49       0.57      0.47      0.52        34
#           50       0.52      0.73      0.61        15
#           51       0.57      0.39      0.47       175
#           52       0.76      0.82      0.79        61
#           53       0.50      0.25      0.33         4
#           54       0.81      0.84      0.82       215
#           55       0.60      0.43      0.50         7
#           56       1.00      0.67      0.80         6
#           57       0.86      0.46      0.60        13
#           58       0.50      0.08      0.14        12
#           59       0.45      0.19      0.27        26
#           60       1.00      0.22      0.36         9
#           61       0.68      0.67      0.67        60
#           62       0.67      0.33      0.44        18
#           63       0.72      0.52      0.61        84
#           64       0.50      0.42      0.45        24
#           65       1.00      1.00      1.00         7
#           66       0.78      0.71      0.75        35
#           67       0.56      0.52      0.54        77
#           68       0.70      0.65      0.67       235
#           69       0.00      0.00      0.00         1
#           70       0.70      0.64      0.66       151
#           71       0.50      0.20      0.29        10
#           72       1.00      0.20      0.33         5
#           73       0.73      0.88      0.80        93
#           74       1.00      0.43      0.60        14
#           75       0.88      0.96      0.92        24
#           76       0.83      0.45      0.59        11
#           77       0.83      0.90      0.86        49
#           78       0.50      0.56      0.53         9
#           79       0.00      0.00      0.00         3
#           80       0.75      0.50      0.60        18
#           81       0.00      0.00      0.00         1
#           82       0.80      0.80      0.80        15
#           83       0.33      0.17      0.22         6
#           84       0.74      0.63      0.68       209
#           85       0.66      0.82      0.73       104
#           86       0.66      0.70      0.68        53
#           87       0.00      0.00      0.00         1
#           88       0.79      1.00      0.88        19
#           89       0.78      1.00      0.88         7
#           90       0.57      0.85      0.68        33
#           91       0.79      0.74      0.76       104
#           92       0.00      0.00      0.00         1
#           93       0.50      0.41      0.45       138
#           94       0.00      0.00      0.00         4
#           95       0.82      0.84      0.83       933
#           96       0.60      0.67      0.63         9
#           97       0.45      0.22      0.29        23
#           98       0.77      0.67      0.72        49
#           99       0.00      0.00      0.00         7
#          100       0.83      0.48      0.61        21
#          101       0.50      0.31      0.38        36
#          102       0.00      0.00      0.00         2
#          103       0.75      0.80      0.77        30
#          104       0.56      0.42      0.48        12
#          105       0.15      0.29      0.20         7
#          106       0.00      0.00      0.00         7
#          107       0.85      0.86      0.86       812
#          108       0.85      0.87      0.86        63
#          109       0.58      1.00      0.74         7
#          110       0.60      1.00      0.75         3
#          111       0.75      0.75      0.75        55
#          112       0.75      0.33      0.46        45
#          113       0.33      0.05      0.09        19
#          114       0.80      0.57      0.67         7
#          115       0.75      0.81      0.78        95
#          116       0.00      0.00      0.00         6
#          117       0.62      0.59      0.61        56
#          118       0.76      0.78      0.77       130
#          119       0.66      0.74      0.70       233
#          120       0.61      0.57      0.59        80
#          121       0.00      0.00      0.00         2
#          122       0.85      1.00      0.92        11
#
#     accuracy                           0.70      8648
#    macro avg       0.54      0.49      0.50      8648
# weighted avg       0.69      0.70      0.69      8648

# %%
##-------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
grouped = data.groupby('label')

# Initialize an empty list to store the sampled DataFrames
sampled_dfs = []

# Iterate over each group
for _, group_df in grouped:
    # Sample up to 50 entries from each group
    sampled_df = group_df.sample(min(50, len(group_df)))
    # Append the sampled DataFrame to the list
    sampled_dfs.append(sampled_df)

# Concatenate the sampled DataFrames into a single DataFrame
sampled_df = pd.concat(sampled_dfs)

# Shuffle the DataFrame
sampled_df = sampled_df.sample(frac=1).reset_index(drop=True)
final = sampled_df
final

# %%
final['label'].nunique()

# %%
test_df = pd.read_csv("/kaggle/input/hahhasjsjsj/test.csv")
test_df
# Out:
#                                                abstract  \
# 0     the paper introduces the notion of a locally c...
# 1     a bipartite state which is secretly chosen fro...
# 2     this short paper addresses the open problems l...
# 3     we find the symmetry algebras of cosets which ...
# 4     we present the results of the analysis of the ...
# ...                                                 ...
# 8898  background studies show that the u.s. foreign-...
# 8899  we prove uniqueness for the vortex-wave system...
# 8900  we demonstrate sensitivity of the mn 3d valenc...
# 8901  the coexisting regime of spin density wave (sd...
# 8902  software security is becoming a high priority ...
#
#                                                  author  \
# 0                                     Bartosz Zielinski
# 1           Yangjia Li, Runyao Duan, and Mingsheng Ying
# 2                        F\'elix Bou and Carles Noguera
# 3                         Dushyant Kumar, Menika Sharma
# 4     E. Jimenez-Bailon (Universita Roma Tre), M. Sa...
# ...                                                 ...
# 8898  ['James W. Vaupel', 'Danan Gu', 'Matthew E. Du...
# 8899       Christophe Lacave (ICJ), Evelyne Miot (LJLL)
# 8900  K. W. Edmonds, G. van der Laan, N. R. S. Farle...
# 8901  Q. Q. Ge, Z. R. Ye, M. Xu, Y. Zhang, J. Jiang,...
# 8902  David N. Palacio, Daniel McCrystal, Kevin Mora...
#
#                                doi  url  publication month  publication year  \
# 0                              NaN  NaN                NaN               NaN
# 1       10.1103/PhysRevA.82.032339  NaN                NaN               NaN
# 2                              NaN  NaN                NaN               NaN
# 3          10.1007/JHEP08(2019)179  NaN                NaN               NaN
# 4       10.1051/0004-6361:20065566  NaN                NaN               NaN
# ...                            ...  ...                ...               ...
# 8898  10.1371/journal.pone.0037177  NaN                5.0            2012.0
# 8899                           NaN  NaN                NaN               NaN
# 8900    10.1103/PhysRevB.77.113205  NaN                NaN               NaN
# 8901     10.1103/PhysRevX.3.011020  NaN                NaN               NaN
# 8902                           NaN  NaN                NaN               NaN
#
#                                                   title  \
# 0                   Locally coalgebra-Galois extensions
# 1     Local Unambiguous Discrimination with Remainin...
# 2     Solution of some problems in the arithmetical ...
# 3                   Symmetry Algebras of Stringy Cosets
# 4     XMM-Newton view of the double-peaked Fe K-alph...
# ...                                                 ...
# 8898  survival differences among native-born and for...
# 8899  Uniqueness for the vortex-wave system when the...
# 8900  Strain dependence of the Mn anisotropy in ferr...
# 8901  Anisotropic but nodeless superconducting gap i...
# 8902  Learning to Identify Security-Related Issues U...
#
#                           publisher  data_index
# 0                               NaN       22901
# 1                               NaN       47248
# 2                               NaN       27601
# 3                               NaN       36511
# 4                               NaN       15483
# ...                             ...         ...
# 8898                       PLoS ONE       43679
# 8899                            NaN       41425
# 8900                            NaN       46483
# 8901  Phys. Rev. X 3, 011020 (2013)       53461
# 8902                            NaN       30020
#
# [8903 rows x 9 columns]

# %%
test_df.isnull().sum()
# Out:
# abstract              217
# author                 27
# doi                  3712
# url                  8498
# publication month    7499
# publication year     7496
# title                   0
# publisher            5148
# data_index              0
# dtype: int64

# %%
test_df.drop(['doi','url','publication month', 'publication year','publisher', 'author'], axis =1 , inplace = True)
test_df.fillna('', inplace=True)
test_df['text'] = test_df['title'] + test_df['abstract']
test_df['text'] = NLP_cleaning(test_df.text.values.tolist())
test_df = test_df[['text', 'data_index']]
test_df
# Out:
# Cleaning: 100%|██████████| 8903/8903 [00:00<00:00, 12073.50it/s]
#                                                    text  data_index
# 0     locally coalgebra galois extensionsthe paper i...       22901
# 1     local unambiguous discrimination with remainin...       47248
# 2     solution of some problems in the arithmetical ...       27601
# 3     symmetry algebras of stringy cosetswe find the...       36511
# 4     xmm newton view of the double peaked fe k alph...       15483
# ...                                                 ...         ...
# 8898  survival differences among native born and for...       43679
# 8899  uniqueness for the vortex wave system when the...       41425
# 8900  strain dependence of the mn anisotropy in ferr...       46483
# 8901  anisotropic but nodeless superconducting gap i...       53461
# 8902  learning to identify security related issues u...       30020
#
# [8903 rows x 2 columns]

# %%
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
input = test_df['text'].tolist()
input = model.encode(input)
# Out:
# Batches:   0%|          | 0/279 [00:00<?, ?it/s]

# %%
preds = final_model.predict(input)

# %%
preds
# Out:
# array([  0, 107, 120, ...,  68,  73,  35])

# %%
preds = label_encoder.inverse_transform(preds)

# %%
submission = pd.DataFrame()
submission['data_index'] = test_df['data_index']
submission['target'] = preds
submission
# Out:
#       data_index                             target
# 0          22901                            Algebra
# 1          47248                    Quantum Physics
# 2          27601                  Theory/Algorithms
# 3          36511                    Quantum Physics
# 4          15483         Astrophysics and Astronomy
# ...          ...                                ...
# 8898       43679                     Bioinformatics
# 8899       41425         Dynamics/Dynamical Systems
# 8900       46483  Materials Science and Engineering
# 8901       53461             Mechanics of Materials
# 8902       30020          Cryptography and Security
#
# [8903 rows x 2 columns]

# %%
import zipfile
submission.to_csv('predictions.csv')
zipfile.ZipFile('predictions.zip', mode='w').write("predictions.csv")
